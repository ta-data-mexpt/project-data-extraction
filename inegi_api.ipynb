# %% [markdown]
# INEGI

# %%
import requests
import json
import pandas as pd

# %%
token = 'f4bbad70-1736-d9ba-2932-8d5b28f18d77'
#webpage: https://www.inegi.org.mx/servicios/api_indicadores.html

# %%
#Inflacion
url_1 = 'https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/628208/es/0700/false/BIE/2.0/f4bbad70-1736-d9ba-2932-8d5b28f18d77?type=json'

# %%
response = requests.get(url_1)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'Header': {'Name': 'Datos compactos BIE',
#   'Email': 'atencion.usuarios@inegi.org.mx'},
#  'Series': [{'INDICADOR': '628208',
#    'FREQ': '8',
#    'TOPIC': '100005000015002001000035',
#    'UNIT': '60',
#    'NOTE': '',
#    'SOURCE': '127',
#    'LASTUPDATE': '07/05/2021 01:51:47 p. m.',
#    'STATUS': None,
#    'OBSERVATIONS': [{'TIME_PERIOD': '2021/04',
#      'OBS_VALUE': '6.08',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '127',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/03',
#      'OBS_VALUE': '4.67',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '127',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/02',
#      'OBS_VALUE': '3.76',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '127',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/01',
#      'OBS_VALUE': '3.54',
# ...

# %%
Serie_1 = response.json() ['Series'][0]['OBSERVATIONS']
Serie_1
# Out:
# [{'TIME_PERIOD': '2021/04',
#   'OBS_VALUE': '6.08',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '127',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/03',
#   'OBS_VALUE': '4.67',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '127',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/02',
#   'OBS_VALUE': '3.76',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '127',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/01',
#   'OBS_VALUE': '3.54',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '127',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/12',
#   'OBS_VALUE': '3.15',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '127',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/11',
#   'OBS_VALUE': '3.33',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '127',
# ...

# %%
Fecha = []

for obs in Serie_1:
    Fecha.append(str(obs['TIME_PERIOD']))

Valor = []

for obs in Serie_1:
    Valor.append(float(obs['OBS_VALUE']))

df = pd.DataFrame(list(zip(Fecha,Valor)), columns = ['Periodo','Inflación anual (Var. Anual %)'])
df
# Out:
#      Periodo  Inflación anual (Var. Anual %)
# 0    2021/04                            6.08
# 1    2021/03                            4.67
# 2    2021/02                            3.76
# 3    2021/01                            3.54
# 4    2020/12                            3.15
# ..       ...                             ...
# 611  1970/05                            5.09
# 612  1970/04                            4.87
# 613  1970/03                            5.01
# 614  1970/02                            4.81
# 615  1970/01                            5.20
#
# [616 rows x 2 columns]

# %%
#Consumo privado:
url_2 = 'https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/497618/es/0700/false/BIE/2.0/f4bbad70-1736-d9ba-2932-8d5b28f18d77?type=json'

# %%
response = requests.get(url_2)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'Header': {'Name': 'Datos compactos BIE',
#   'Email': 'atencion.usuarios@inegi.org.mx'},
#  'Series': [{'INDICADOR': '497618',
#    'FREQ': '8',
#    'TOPIC': '10000277001000300010',
#    'UNIT': '60',
#    'NOTE': '',
#    'SOURCE': '17',
#    'LASTUPDATE': '11/05/2021 02:36:02 p. m.',
#    'STATUS': None,
#    'OBSERVATIONS': [{'TIME_PERIOD': '2021/02',
#      'OBS_VALUE': '-7.511062340563',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '17',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/01',
#      'OBS_VALUE': '-7.581400679428',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '17',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2020/12',
#      'OBS_VALUE': '-5.316900084955',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '17',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2020/11',
# ...

# %%
Serie_2 = response.json() ['Series'][0]['OBSERVATIONS']
Serie_2
# Out:
# [{'TIME_PERIOD': '2021/02',
#   'OBS_VALUE': '-7.511062340563',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/01',
#   'OBS_VALUE': '-7.581400679428',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/12',
#   'OBS_VALUE': '-5.316900084955',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/11',
#   'OBS_VALUE': '-7.356273911719',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/10',
#   'OBS_VALUE': '-10.058373400287',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/09',
#   'OBS_VALUE': '-9.831633640015',
# ...

# %%
Fecha = []

for obs in Serie_2:
    Fecha.append(str(obs['TIME_PERIOD']))

Valor = []

for obs in Serie_2:
    Valor.append(float(obs['OBS_VALUE']))

df = pd.DataFrame(list(zip(Fecha,Valor)), columns = ['Periodo','Consumo Privado (Var. Anual %)'])
df
# Out:
#      Periodo  Consumo Privado (Var. Anual %)
# 0    2021/02                       -7.511062
# 1    2021/01                       -7.581401
# 2    2020/12                       -5.316900
# 3    2020/11                       -7.356274
# 4    2020/10                      -10.058373
# ..       ...                             ...
# 321  1994/05                        4.815904
# 322  1994/04                        5.909735
# 323  1994/03                        1.286155
# 324  1994/02                        3.579628
# 325  1994/01                        3.995464
#
# [326 rows x 2 columns]

# %%
#Indicador coincidente
url_3 = 'https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/214293/es/0700/false/BIE/2.0/f4bbad70-1736-d9ba-2932-8d5b28f18d77?type=json'

# %%
response = requests.get(url_3)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'Header': {'Name': 'Datos compactos BIE',
#   'Email': 'atencion.usuarios@inegi.org.mx'},
#  'Series': [{'INDICADOR': '214293',
#    'FREQ': '8',
#    'TOPIC': '10000215005000500050',
#    'UNIT': '204',
#    'NOTE': '',
#    'SOURCE': '118',
#    'LASTUPDATE': '04/05/2021 03:48:07 p. m.',
#    'STATUS': None,
#    'OBSERVATIONS': [{'TIME_PERIOD': '2021/02',
#      'OBS_VALUE': '98.131862144182',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '118',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/01',
#      'OBS_VALUE': '97.937087979898',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '118',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2020/12',
#      'OBS_VALUE': '97.823871844636',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '118',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2020/11',
# ...

# %%
Serie_3 = response.json() ['Series'][0]['OBSERVATIONS']
Serie_3
# Out:
# [{'TIME_PERIOD': '2021/02',
#   'OBS_VALUE': '98.131862144182',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '118',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/01',
#   'OBS_VALUE': '97.937087979898',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '118',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/12',
#   'OBS_VALUE': '97.823871844636',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '118',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/11',
#   'OBS_VALUE': '97.850769499401',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '118',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/10',
#   'OBS_VALUE': '97.42066392281',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '118',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/09',
#   'OBS_VALUE': '97.086533341359',
# ...

# %%
Fecha = []

for obs in Serie_3:
    Fecha.append(str(obs['TIME_PERIOD']))

Valor = []

for obs in Serie_3:
    Valor.append(float(obs['OBS_VALUE']))

df = pd.DataFrame(list(zip(Fecha,Valor)), columns = ['Periodo','Indicador coincidente (Puntos)'])
df
# Out:
#      Periodo  Indicador coincidente (Puntos)
# 0    2021/02                       98.131862
# 1    2021/01                       97.937088
# 2    2020/12                       97.823872
# 3    2020/11                       97.850769
# 4    2020/10                       97.420664
# ..       ...                             ...
# 489  1980/05                       98.645712
# 490  1980/04                       98.367871
# 491  1980/03                       98.109244
# 492  1980/02                       97.855433
# 493  1980/01                       97.603469
#
# [494 rows x 2 columns]

# %%
#Indicador adelantado
url_4 = 'https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/214307/es/0700/false/BIE/2.0/f4bbad70-1736-d9ba-2932-8d5b28f18d77?type=json'

# %%
response = requests.get(url_4)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'Header': {'Name': 'Datos compactos BIE',
#   'Email': 'atencion.usuarios@inegi.org.mx'},
#  'Series': [{'INDICADOR': '214307',
#    'FREQ': '8',
#    'TOPIC': '10000215007000700050',
#    'UNIT': '204',
#    'NOTE': '',
#    'SOURCE': '118',
#    'LASTUPDATE': '04/05/2021 03:48:07 p. m.',
#    'STATUS': None,
#    'OBSERVATIONS': [{'TIME_PERIOD': '2021/03',
#      'OBS_VALUE': '101.779028457593',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '118',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/02',
#      'OBS_VALUE': '101.51691585533',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '118',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/01',
#      'OBS_VALUE': '101.238252338238',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '118',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2020/12',
# ...

# %%
Serie_4 = response.json() ['Series'][0]['OBSERVATIONS']
Serie_4
# Out:
# [{'TIME_PERIOD': '2021/03',
#   'OBS_VALUE': '101.779028457593',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '118',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/02',
#   'OBS_VALUE': '101.51691585533',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '118',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/01',
#   'OBS_VALUE': '101.238252338238',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '118',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/12',
#   'OBS_VALUE': '100.921011155715',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '118',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/11',
#   'OBS_VALUE': '100.562750701335',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '118',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/10',
#   'OBS_VALUE': '100.176114376889',
# ...

# %%
Fecha = []

for obs in Serie_4:
    Fecha.append(str(obs['TIME_PERIOD']))

Valor = []

for obs in Serie_4:
    Valor.append(float(obs['OBS_VALUE']))

df = pd.DataFrame(list(zip(Fecha,Valor)), columns = ['Periodo','Indicador adelantado (Puntos)'])
df
# Out:
#      Periodo  Indicador adelantado (Puntos)
# 0    2021/03                     101.779028
# 1    2021/02                     101.516916
# 2    2021/01                     101.238252
# 3    2020/12                     100.921011
# 4    2020/11                     100.562751
# ..       ...                            ...
# 490  1980/05                     101.537547
# 491  1980/04                     101.319195
# 492  1980/03                     101.199695
# 493  1980/02                     101.132260
# 494  1980/01                     101.067649
#
# [495 rows x 2 columns]

# %%
#Confianza del consumidor
url_5 = 'https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/454168/es/0700/false/BIE/2.0/f4bbad70-1736-d9ba-2932-8d5b28f18d77?type=json'

# %%
response = requests.get(url_5)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'Header': {'Name': 'Datos compactos BIE',
#   'Email': 'atencion.usuarios@inegi.org.mx'},
#  'Series': [{'INDICADOR': '454168',
#    'FREQ': '8',
#    'TOPIC': '10000480042100450010',
#    'UNIT': '204',
#    'NOTE': '3011',
#    'SOURCE': '64',
#    'LASTUPDATE': '07/05/2021 01:51:47 p. m.',
#    'STATUS': None,
#    'OBSERVATIONS': [{'TIME_PERIOD': '2021/04',
#      'OBS_VALUE': '42.509073150799',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '64',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/03',
#      'OBS_VALUE': '40.581572053441',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '64',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/02',
#      'OBS_VALUE': '38.640136961085',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '64',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/01',
# ...

# %%
Serie_5 = response.json() ['Series'][0]['OBSERVATIONS']
Serie_5
# Out:
# [{'TIME_PERIOD': '2021/04',
#   'OBS_VALUE': '42.509073150799',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '64',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/03',
#   'OBS_VALUE': '40.581572053441',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '64',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/02',
#   'OBS_VALUE': '38.640136961085',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '64',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/01',
#   'OBS_VALUE': '39.211395346757',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '64',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/12',
#   'OBS_VALUE': '38.748705307192',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '64',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/11',
#   'OBS_VALUE': '37.076740993337',
# ...

# %%
Fecha = []

for obs in Serie_5:
    Fecha.append(str(obs['TIME_PERIOD']))

Valor = []

for obs in Serie_5:
    Valor.append(float(obs['OBS_VALUE']))

df = pd.DataFrame(list(zip(Fecha,Valor)), columns = ['Periodo','Confianza del consumidor(Índice))'])
df
# Out:
#      Periodo  Confianza del consumidor(Índice))
# 0    2021/04                          42.509073
# 1    2021/03                          40.581572
# 2    2021/02                          38.640137
# 3    2021/01                          39.211395
# 4    2020/12                          38.748705
# ..       ...                                ...
# 236  2001/08                          47.693093
# 237  2001/07                          46.874405
# 238  2001/06                          44.568246
# 239  2001/05                          45.186165
# 240  2001/04                          46.629247
#
# [241 rows x 2 columns]

# %%
#Tasa de ocupación parcial y desocupación
url_6 = 'https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/444603/es/0700/false/BIE/2.0/f4bbad70-1736-d9ba-2932-8d5b28f18d77?type=json'

# %%
response = requests.get(url_6)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'Header': {'Name': 'Datos compactos BIE',
#   'Email': 'atencion.usuarios@inegi.org.mx'},
#  'Series': [{'INDICADOR': '444603',
#    'FREQ': '8',
#    'TOPIC': '10000080018000700203',
#    'UNIT': '136',
#    'NOTE': '2876',
#    'SOURCE': '272',
#    'LASTUPDATE': '22/04/2021 03:41:06 p. m.',
#    'STATUS': None,
#    'OBSERVATIONS': [{'TIME_PERIOD': '2021/03',
#      'OBS_VALUE': '3.894450685886',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '272',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/02',
#      'OBS_VALUE': '4.374475733076',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '272',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/01',
#      'OBS_VALUE': '4.73382237731',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '272',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2020/12',
# ...

# %%
Serie_6 = response.json() ['Series'][0]['OBSERVATIONS']
Serie_6
# Out:
# [{'TIME_PERIOD': '2021/03',
#   'OBS_VALUE': '3.894450685886',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '272',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/02',
#   'OBS_VALUE': '4.374475733076',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '272',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/01',
#   'OBS_VALUE': '4.73382237731',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '272',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/12',
#   'OBS_VALUE': '3.802891941827',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '272',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/11',
#   'OBS_VALUE': '4.371151017155',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '272',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/10',
#   'OBS_VALUE': '4.697674962554',
# ...

# %%
Fecha = []

for obs in Serie_6:
    Fecha.append(str(obs['TIME_PERIOD']))

Valor = []

for obs in Serie_6:
    Valor.append(float(obs['OBS_VALUE']))

df = pd.DataFrame(list(zip(Fecha,Valor)), columns = ['Periodo','Tasa de desocupación(%))'])
df
# Out:
#      Periodo  Tasa de desocupación(%))
# 0    2021/03                  3.894451
# 1    2021/02                  4.374476
# 2    2021/01                  4.733822
# 3    2020/12                  3.802892
# 4    2020/11                  4.371151
# ..       ...                       ...
# 190  2005/05                  3.303693
# 191  2005/04                  3.363412
# 192  2005/03                  3.627075
# 193  2005/02                  3.773302
# 194  2005/01                  3.951998
#
# [195 rows x 2 columns]

# %%
#IGAE
url_7 = 'https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/496166/es/0700/false/BIE/2.0/f4bbad70-1736-d9ba-2932-8d5b28f18d77?type=json'

# %%
response = requests.get(url_7)

# %%
response
# Out:
# <Response [200]>

# %%
request.json()
# Out:
# {'Header': {'Name': 'Datos compactos BIE',
#   'Email': 'atencion.usuarios@inegi.org.mx'},
#  'Series': [{'INDICADOR': '496166',
#    'FREQ': '8',
#    'TOPIC': '10000202013600450080',
#    'UNIT': '60',
#    'NOTE': '',
#    'SOURCE': '17',
#    'LASTUPDATE': '26/04/2021 03:49:58 p. m.',
#    'STATUS': None,
#    'OBSERVATIONS': [{'TIME_PERIOD': '2021/02',
#      'OBS_VALUE': '-5.063785301667',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '17',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/01',
#      'OBS_VALUE': '-5.434728298347',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '17',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2020/12',
#      'OBS_VALUE': '-2.676895752868',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '17',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2020/11',
# ...

# %%
Serie_7 = response.json() ['Series'][0]['OBSERVATIONS']
Serie_7
# Out:
# [{'TIME_PERIOD': '2021/02',
#   'OBS_VALUE': '-5.063785301667',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/01',
#   'OBS_VALUE': '-5.434728298347',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/12',
#   'OBS_VALUE': '-2.676895752868',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/11',
#   'OBS_VALUE': '-4.149898673745',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/10',
#   'OBS_VALUE': '-5.309833555711',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/09',
#   'OBS_VALUE': '-5.394923099191',
# ...

# %%
Fecha = []

for obs in Serie_7:
    Fecha.append(str(obs['TIME_PERIOD']))

Valor = []

for obs in Serie_7:
    Valor.append(float(obs['OBS_VALUE']))

df = pd.DataFrame(list(zip(Fecha,Valor)), columns = ['Periodo','IGAE(Var. Anual %))'])
df
# Out:
#      Periodo  IGAE(Var. Anual %))
# 0    2021/02            -5.063785
# 1    2021/01            -5.434728
# 2    2020/12            -2.676896
# 3    2020/11            -4.149899
# 4    2020/10            -5.309834
# ..       ...                  ...
# 321  1994/05             5.102585
# 322  1994/04             6.507182
# 323  1994/03             2.888538
# 324  1994/02             2.803284
# 325  1994/01             4.339807
#
# [326 rows x 2 columns]

# %%
#Actividad industrial
url_8 = 'https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/496360/es/0700/false/BIE/2.0/f4bbad70-1736-d9ba-2932-8d5b28f18d77?type=json'

# %%
response = requests.get(url_8)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'Header': {'Name': 'Datos compactos BIE',
#   'Email': 'atencion.usuarios@inegi.org.mx'},
#  'Series': [{'INDICADOR': '496360',
#    'FREQ': '8',
#    'TOPIC': '10000292013000900070',
#    'UNIT': '60',
#    'NOTE': '3026',
#    'SOURCE': '17',
#    'LASTUPDATE': '12/05/2021 06:34:41 p. m.',
#    'STATUS': None,
#    'OBSERVATIONS': [{'TIME_PERIOD': '2021/03',
#      'OBS_VALUE': '1.653877230436',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '1',
#      'OBS_SOURCE': '17',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/02',
#      'OBS_VALUE': '-4.534216879837',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '17',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2021/01',
#      'OBS_VALUE': '-5.022025584548',
#      'OBS_EXCEPTION': '',
#      'OBS_STATUS': '',
#      'OBS_SOURCE': '17',
#      'OBS_NOTE': None,
#      'COBER_GEO': '00'},
#     {'TIME_PERIOD': '2020/12',
# ...

# %%
Serie_8 = response.json() ['Series'][0]['OBSERVATIONS']
Serie_8
# Out:
# [{'TIME_PERIOD': '2021/03',
#   'OBS_VALUE': '1.653877230436',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '1',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/02',
#   'OBS_VALUE': '-4.534216879837',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2021/01',
#   'OBS_VALUE': '-5.022025584548',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/12',
#   'OBS_VALUE': '-2.272652370878',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/11',
#   'OBS_VALUE': '-3.926852219463',
#   'OBS_EXCEPTION': '',
#   'OBS_STATUS': '',
#   'OBS_SOURCE': '17',
#   'OBS_NOTE': None,
#   'COBER_GEO': '00'},
#  {'TIME_PERIOD': '2020/10',
#   'OBS_VALUE': '-3.505668913135',
# ...

# %%
Fecha = []

for obs in Serie_8:
    Fecha.append(str(obs['TIME_PERIOD']))

Valor = []

for obs in Serie_8:
    Valor.append(float(obs['OBS_VALUE']))

df = pd.DataFrame(list(zip(Fecha,Valor)), columns = ['Periodo','Actividad industrial (Var. Anual %))'])
df
# Out:
#      Periodo  Actividad industrial (Var. Anual %))
# 0    2021/03                              1.653877
# 1    2021/02                             -4.534217
# 2    2021/01                             -5.022026
# 3    2020/12                             -2.272652
# 4    2020/11                             -3.926852
# ..       ...                                   ...
# 322  1994/05                              4.739569
# 323  1994/04                              9.694080
# 324  1994/03                              3.390675
# 325  1994/02                              3.724170
# 326  1994/01                              5.820409
#
# [327 rows x 2 columns]
