# %%
import json
import requests
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
from urllib.request import urlopen

# %%
# Datos Generales pokemon

df=pd.DataFrame()


for i in range(1,151):
    url = f'https://pokeapi.co/api/v2/pokemon/{i}/'
    response = requests.get(url)
    if response.status_code == 200:
           
        results = response.json()
        flattened_data = json_normalize(results)
        df = df.append(flattened_data)
        
    else:
        print('connection error')
        break
print('Connecion Successful')
# Out:
# <ipython-input-2-611f56b83ea7>:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# Connecion Successful

# %%
df.index = np.arange(1,len(df)+1)

# %%
ids = [df['id'][i] for i in range(1,151)]

# %%
names = [df['forms'][i][0]['name'] for i in range(1,151)]

# %%
attacks = [df['moves'][i][0]['move']['name'] for i in range(1,151)]

# %%
links_pictures = [df['sprites.versions.generation-vi.x-y.front_shiny'][i] for i in range(1,151)]

# %%
# Para obtener el tipo de pokemon

df2=pd.DataFrame()


for i in range(1,151):
    url = f'https://pokeapi.co/api/v2/pokemon-form/{i}/'
    response = requests.get(url)
    if response.status_code == 200:
        
        results = response.json()
        flattened_data = json_normalize(results)
        df2 = df2.append(flattened_data)
    else:
        print('connection error')
        break

print('Connecion Successful')
# Out:
# <ipython-input-65-4b281ad6ec19>:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# Connecion Successful

# %%
df2.index = np.arange(1,len(df2)+1)

# %%
types = [df2['types'][i][0]['type']['name'] for i in range(1,151)]

# %%
# Para obtener las fotos de pokemons por la parte de atrás

df3=pd.DataFrame()

for i in range(1,151):
    url = f'https://pokeapi.co/api/v2/pokemon-form/{i}/'
    response = requests.get(url)
    if response.status_code == 200:
           
        results = response.json()
        flattened_data = json_normalize(results)
        flattened_data = flattened_data.set_index('id')
        df3 = df3.append(flattened_data)
        
    else:
        print('connection error')
        break
print('Connecion Successful')
# Out:
# <ipython-input-69-2d7dd35f0db3>:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# Connecion Successful

# %%
df3.index = np.arange(1,len(df3)+1)

# %%
links_pictures_back = [df3['sprites.back_default'][i] for i in range(1,151)]

# %%
nom_columns = ['Id','Pokemon','Type','Hard Attack','Picture','Back _Picture']

# %%
df_pokemon = pd.DataFrame(list(zip(ids, names, types,  attacks, links_pictures, links_pictures_back )), columns = nom_columns)

# %%
df_pokemon = df_pokemon.set_index('Id')

# %%
df_pokemon['Picture'][25]
# Out:
# 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/x-y/shiny/25.png'

# %%
df_pokemon['Back _Picture'][25]
# Out:
# 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/25.png'

# %%
df_pokemon.head(50)
# Out:
#        Pokemon      Type   Hard Attack  \
# Id
# 1    bulbasaur     grass    razor-wind
# 2      ivysaur     grass  swords-dance
# 3     venusaur     grass  swords-dance
# 4   charmander      fire    mega-punch
# 5   charmeleon      fire    mega-punch
# 6    charizard      fire    mega-punch
# 7     squirtle     water    mega-punch
# 8    wartortle     water    mega-punch
# 9    blastoise     water    mega-punch
# 10    caterpie       bug        tackle
# 11     metapod       bug   string-shot
# 12  butterfree       bug    razor-wind
# 13      weedle       bug  poison-sting
# 14      kakuna       bug   string-shot
# 15    beedrill       bug  swords-dance
# 16      pidgey    normal    razor-wind
# 17   pidgeotto    normal    razor-wind
# 18     pidgeot    normal    razor-wind
# 19     rattata    normal           cut
# 20    raticate    normal  swords-dance
# 21     spearow    normal    razor-wind
# 22      fearow    normal    razor-wind
# 23       ekans    poison          bind
# ...

# %%
df_pokemon.to_csv('Exports/Pokemons.csv')
