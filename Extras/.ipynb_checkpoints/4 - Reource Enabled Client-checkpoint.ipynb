# %%
# Coneccion a la API de Spotify
client_id = '2fcf86918d5d434c90fe82b1294d12b0'
client_secret = 'd7fa0a4a43fb4fff9cc3bce1940ff876'

# %%
import base64
import requests
import datetime
from urllib.parse import urlencode
import pandas as pd

class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    client_id = None
    client_secret = None
    access_token_did_expire = True
    token_url = 'https://accounts.spotify.com/api/token'
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args,**kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        """ returns a base64 encoded string """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
            
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())        
        return client_creds_b64.decode()
        
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        
        return {
            "Authorization":f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type":"client_credentials"
        }
    
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        
        r = requests.post(token_url, data = token_data, headers = token_headers)

        if r.status_code not in range(200,299):
            raise Exceptiontion('Could not authenticate client')
            #return False
            
        data = r.json()
        now = datetime.datetime.now()
        acces_token = data['access_token']
        expires_in = data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds = expires_in)
        self.access_token = acces_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization":f"Bearer {access_token}"
        }
        return headers
        
    
    def get_resource(self,lookup_id,resource_type ='albums',version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_header()
        r = requests.get(endpoint,headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type = 'albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type = 'artists')
    
    def search(self,query,search_type='artist'):
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q":query,"type":search_type.lower()})
        lookup_url = f"{endpoint}?{data}"
        print(lookup_url)
        r = requests.get(lookup_url, headers = headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()

# %%
spotify = SpotifyAPI(client_id,client_secret)

# %%
spotify.search('Wolfs',search_type='Track')
# Out:
# https://api.spotify.com/v1/search?q=Wolfs&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Wolfs&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cXi8ALPQCBHZbf0EgP4Ey'},
#        'href': 'https://api.spotify.com/v1/artists/1cXi8ALPQCBHZbf0EgP4Ey',
#        'id': '1cXi8ALPQCBHZbf0EgP4Ey',
#        'name': 'Misfits',
#        'type': 'artist',
#        'uri': 'spotify:artist:1cXi8ALPQCBHZbf0EgP4Ey'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4pEcCqGx1RFaXWJD0mrG10'},
#      'href': 'https://api.spotify.com/v1/albums/4pEcCqGx1RFaXWJD0mrG10',
#      'id': '4pEcCqGx1RFaXWJD0mrG10',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d5446acf2c34078e85f58de2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d5446acf2c34078e85f58de2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d5446acf2c34078e85f58de2',
#        'width': 64}],
#      'name': 'Collection',
#      'release_date': '1986-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:4pEcCqGx1RFaXWJD0mrG10'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cXi8ALPQCBHZbf0EgP4Ey'},
#       'href': 'https://api.spotify.com/v1/artists/1cXi8ALPQCBHZbf0EgP4Ey',
#       'id': '1cXi8ALPQCBHZbf0EgP4Ey',
#       'name': 'Misfits',
#       'type': 'artist',
#       'uri': 'spotify:artist:1cXi8ALPQCBHZbf0EgP4Ey'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 71600,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCN38300022'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2NyGWqtkTjufgHGUL5EjSX'},
#     'href': 'https://api.spotify.com/v1/tracks/2NyGWqtkTjufgHGUL5EjSX',
#     'id': '2NyGWqtkTjufgHGUL5EjSX',
#     'is_local': False,
#     'name': 'Wolfs Blood',
#     'popularity': 32,
#     'preview_url': None,
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:2NyGWqtkTjufgHGUL5EjSX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69lt02nubfNbPdrvH4tJxx'},
#        'href': 'https://api.spotify.com/v1/artists/69lt02nubfNbPdrvH4tJxx',
#        'id': '69lt02nubfNbPdrvH4tJxx',
#        'name': 'Gorod',
#        'type': 'artist',
#        'uri': 'spotify:artist:69lt02nubfNbPdrvH4tJxx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5XZmjfpxRFqhv4iv2GDjYV'},
#      'href': 'https://api.spotify.com/v1/albums/5XZmjfpxRFqhv4iv2GDjYV',
#      'id': '5XZmjfpxRFqhv4iv2GDjYV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730a64b0507d137a0e533e8a37',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020a64b0507d137a0e533e8a37',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510a64b0507d137a0e533e8a37',
#        'width': 64}],
#      'name': 'Aethra',
#      'release_date': '2018-10-19',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5XZmjfpxRFqhv4iv2GDjYV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69lt02nubfNbPdrvH4tJxx'},
#       'href': 'https://api.spotify.com/v1/artists/69lt02nubfNbPdrvH4tJxx',
#       'id': '69lt02nubfNbPdrvH4tJxx',
#       'name': 'Gorod',
#       'type': 'artist',
#       'uri': 'spotify:artist:69lt02nubfNbPdrvH4tJxx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 267293,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR8FM1800075'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3tBcNgxfwCnZrttLtssqj9'},
#     'href': 'https://api.spotify.com/v1/tracks/3tBcNgxfwCnZrttLtssqj9',
#     'id': '3tBcNgxfwCnZrttLtssqj9',
#     'is_local': False,
#     'name': 'Wolfsmond',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8ce9c14ded8b83faaf4c3b69f233ca0517df2fd4?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3tBcNgxfwCnZrttLtssqj9'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Sg7AbBKgfZ8VJ6dAlf0oe'},
#      'href': 'https://api.spotify.com/v1/albums/3Sg7AbBKgfZ8VJ6dAlf0oe',
#      'id': '3Sg7AbBKgfZ8VJ6dAlf0oe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27304a41169a22370412db3a59e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0204a41169a22370412db3a59e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485104a41169a22370412db3a59e',
#        'width': 64}],
#      'name': 'Begin To Wisper',
#      'release_date': '2020-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:3Sg7AbBKgfZ8VJ6dAlf0oe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7lFjQ8UzvZMyQKZi83HDQG'},
#       'href': 'https://api.spotify.com/v1/artists/7lFjQ8UzvZMyQKZi83HDQG',
#       'id': '7lFjQ8UzvZMyQKZi83HDQG',
#       'name': 'Caelan Nerney',
#       'type': 'artist',
#       'uri': 'spotify:artist:7lFjQ8UzvZMyQKZi83HDQG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 161255,
#     'explicit': False,
#     'external_ids': {'isrc': 'CA5KR2032066'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1UfiM3tQBIiYHopcR2q0dk'},
#     'href': 'https://api.spotify.com/v1/tracks/1UfiM3tQBIiYHopcR2q0dk',
#     'id': '1UfiM3tQBIiYHopcR2q0dk',
#     'is_local': False,
#     'name': 'Wolfsbane',
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9ceae1504ab61b659185a57f333634e08d1ff938?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1UfiM3tQBIiYHopcR2q0dk'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2yVE8rF1Gos332sWFHuWvq'},
#        'href': 'https://api.spotify.com/v1/artists/2yVE8rF1Gos332sWFHuWvq',
#        'id': '2yVE8rF1Gos332sWFHuWvq',
#        'name': 'Shredders',
#        'type': 'artist',
#        'uri': 'spotify:artist:2yVE8rF1Gos332sWFHuWvq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3khO7vfDAQDiD6lx1atVCe'},
#      'href': 'https://api.spotify.com/v1/albums/3khO7vfDAQDiD6lx1atVCe',
#      'id': '3khO7vfDAQDiD6lx1atVCe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b5ca49601a6072609295eaa0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b5ca49601a6072609295eaa0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b5ca49601a6072609295eaa0',
#        'width': 64}],
#      'name': 'Shredders',
#      'release_date': '2017-07-11',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:3khO7vfDAQDiD6lx1atVCe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2yVE8rF1Gos332sWFHuWvq'},
#       'href': 'https://api.spotify.com/v1/artists/2yVE8rF1Gos332sWFHuWvq',
#       'id': '2yVE8rF1Gos332sWFHuWvq',
#       'name': 'Shredders',
#       'type': 'artist',
#       'uri': 'spotify:artist:2yVE8rF1Gos332sWFHuWvq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 177131,
#     'explicit': True,
#     'external_ids': {'isrc': 'QMLD61407974'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3LHYIZMuiIb8f1F5UvBH8A'},
#     'href': 'https://api.spotify.com/v1/tracks/3LHYIZMuiIb8f1F5UvBH8A',
#     'id': '3LHYIZMuiIb8f1F5UvBH8A',
#     'is_local': False,
#     'name': 'Wolfs',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8791f360f87441964a215737e30a063b9ccadddd?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3LHYIZMuiIb8f1F5UvBH8A'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ebS2RuCq8QeLyndUDmgB5'},
#        'href': 'https://api.spotify.com/v1/artists/3ebS2RuCq8QeLyndUDmgB5',
#        'id': '3ebS2RuCq8QeLyndUDmgB5',
#        'name': 'WizTheMc',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ebS2RuCq8QeLyndUDmgB5'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1TBWWvhaT8b4ItnaIPrVNH'},
#        'href': 'https://api.spotify.com/v1/artists/1TBWWvhaT8b4ItnaIPrVNH',
#        'id': '1TBWWvhaT8b4ItnaIPrVNH',
#        'name': 'Wolfskind',
#        'type': 'artist',
#        'uri': 'spotify:artist:1TBWWvhaT8b4ItnaIPrVNH'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4FB0ZlyDLV9zyvtJLNmZNw'},
#        'href': 'https://api.spotify.com/v1/artists/4FB0ZlyDLV9zyvtJLNmZNw',
#        'id': '4FB0ZlyDLV9zyvtJLNmZNw',
#        'name': 'Bayuk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4FB0ZlyDLV9zyvtJLNmZNw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0c5h3sJO1b5g0gn9J0dnHL'},
#      'href': 'https://api.spotify.com/v1/albums/0c5h3sJO1b5g0gn9J0dnHL',
#      'id': '0c5h3sJO1b5g0gn9J0dnHL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bdbef0bf83c2bae352af3746',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bdbef0bf83c2bae352af3746',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bdbef0bf83c2bae352af3746',
#        'width': 64}],
#      'name': 'On My Mind',
#      'release_date': '2019-11-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0c5h3sJO1b5g0gn9J0dnHL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ebS2RuCq8QeLyndUDmgB5'},
#       'href': 'https://api.spotify.com/v1/artists/3ebS2RuCq8QeLyndUDmgB5',
#       'id': '3ebS2RuCq8QeLyndUDmgB5',
#       'name': 'WizTheMc',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ebS2RuCq8QeLyndUDmgB5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1TBWWvhaT8b4ItnaIPrVNH'},
#       'href': 'https://api.spotify.com/v1/artists/1TBWWvhaT8b4ItnaIPrVNH',
#       'id': '1TBWWvhaT8b4ItnaIPrVNH',
#       'name': 'Wolfskind',
#       'type': 'artist',
#       'uri': 'spotify:artist:1TBWWvhaT8b4ItnaIPrVNH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4FB0ZlyDLV9zyvtJLNmZNw'},
#       'href': 'https://api.spotify.com/v1/artists/4FB0ZlyDLV9zyvtJLNmZNw',
#       'id': '4FB0ZlyDLV9zyvtJLNmZNw',
#       'name': 'Bayuk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4FB0ZlyDLV9zyvtJLNmZNw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 172602,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBKPL1974494'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GmHBGjVvU2OAgezCpOYIM'},
#     'href': 'https://api.spotify.com/v1/tracks/0GmHBGjVvU2OAgezCpOYIM',
#     'id': '0GmHBGjVvU2OAgezCpOYIM',
#     'is_local': False,
#     'name': 'On My Mind',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c26d5ed1f3402feff3e41d922c7b93915a2ae9cc?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0GmHBGjVvU2OAgezCpOYIM'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ku4qKZIc7liX9EROJU4xY'},
#        'href': 'https://api.spotify.com/v1/artists/7ku4qKZIc7liX9EROJU4xY',
#        'id': '7ku4qKZIc7liX9EROJU4xY',
#        'name': 'Cloud Sleep',
#        'type': 'artist',
#        'uri': 'spotify:artist:7ku4qKZIc7liX9EROJU4xY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7rOJTnqnY4II67RXh2uIuU'},
#      'href': 'https://api.spotify.com/v1/albums/7rOJTnqnY4II67RXh2uIuU',
#      'id': '7rOJTnqnY4II67RXh2uIuU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27335860bb174e2e774005add78',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0235860bb174e2e774005add78',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485135860bb174e2e774005add78',
#        'width': 64}],
#      'name': 'Atrium',
#      'release_date': '2020-06-04',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:7rOJTnqnY4II67RXh2uIuU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ku4qKZIc7liX9EROJU4xY'},
#       'href': 'https://api.spotify.com/v1/artists/7ku4qKZIc7liX9EROJU4xY',
#       'id': '7ku4qKZIc7liX9EROJU4xY',
#       'name': 'Cloud Sleep',
#       'type': 'artist',
#       'uri': 'spotify:artist:7ku4qKZIc7liX9EROJU4xY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 150961,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHN52083373'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6oQTT2cAwp9O2Imjqv73k6'},
#     'href': 'https://api.spotify.com/v1/tracks/6oQTT2cAwp9O2Imjqv73k6',
#     'id': '6oQTT2cAwp9O2Imjqv73k6',
#     'is_local': False,
#     'name': 'Wolfs',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/aee8538b7326c50b6572006e80bd1692fcf0635b?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6oQTT2cAwp9O2Imjqv73k6'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0CBDTLHnL2GQ93c8kdYY0s'},
#        'href': 'https://api.spotify.com/v1/artists/0CBDTLHnL2GQ93c8kdYY0s',
#        'id': '0CBDTLHnL2GQ93c8kdYY0s',
#        'name': 'Denny Schneidemesser',
#        'type': 'artist',
#        'uri': 'spotify:artist:0CBDTLHnL2GQ93c8kdYY0s'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3XVoLW4NDxrJSjioiXbiCN'},
#      'href': 'https://api.spotify.com/v1/albums/3XVoLW4NDxrJSjioiXbiCN',
#      'id': '3XVoLW4NDxrJSjioiXbiCN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273efd1ea057ca25c074428c2a9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02efd1ea057ca25c074428c2a9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851efd1ea057ca25c074428c2a9',
#        'width': 64}],
#      'name': 'The First Five Years',
#      'release_date': '2014-07-05',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:3XVoLW4NDxrJSjioiXbiCN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0CBDTLHnL2GQ93c8kdYY0s'},
#       'href': 'https://api.spotify.com/v1/artists/0CBDTLHnL2GQ93c8kdYY0s',
#       'id': '0CBDTLHnL2GQ93c8kdYY0s',
#       'name': 'Denny Schneidemesser',
#       'type': 'artist',
#       'uri': 'spotify:artist:0CBDTLHnL2GQ93c8kdYY0s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 258390,
#     'explicit': False,
#     'external_ids': {'isrc': 'USE830928366'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/29hCntOkfJina7b9kg5U2k'},
#     'href': 'https://api.spotify.com/v1/tracks/29hCntOkfJina7b9kg5U2k',
#     'id': '29hCntOkfJina7b9kg5U2k',
#     'is_local': False,
#     'name': 'Wolfsong',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fdf9f2e24a02039a681c5cda4c2caf9dac9c5eac?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:29hCntOkfJina7b9kg5U2k'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jVoRoIq6q8cJcHCIOhQvO'},
#        'href': 'https://api.spotify.com/v1/artists/3jVoRoIq6q8cJcHCIOhQvO',
#        'id': '3jVoRoIq6q8cJcHCIOhQvO',
#        'name': 'Leo Rojas',
#        'type': 'artist',
#        'uri': 'spotify:artist:3jVoRoIq6q8cJcHCIOhQvO'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/23F5gXJYGSPnixYyKVU7m1'},
#      'href': 'https://api.spotify.com/v1/albums/23F5gXJYGSPnixYyKVU7m1',
#      'id': '23F5gXJYGSPnixYyKVU7m1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fddfc772770b07d41da1e01e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fddfc772770b07d41da1e01e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fddfc772770b07d41da1e01e',
#        'width': 64}],
#      'name': 'Leo Rojas',
#      'release_date': '2017-11-03',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:23F5gXJYGSPnixYyKVU7m1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jVoRoIq6q8cJcHCIOhQvO'},
#       'href': 'https://api.spotify.com/v1/artists/3jVoRoIq6q8cJcHCIOhQvO',
#       'id': '3jVoRoIq6q8cJcHCIOhQvO',
#       'name': 'Leo Rojas',
#       'type': 'artist',
#       'uri': 'spotify:artist:3jVoRoIq6q8cJcHCIOhQvO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4g3NvD4xvXlUW2iwqCIbiY'},
#       'href': 'https://api.spotify.com/v1/artists/4g3NvD4xvXlUW2iwqCIbiY',
#       'id': '4g3NvD4xvXlUW2iwqCIbiY',
#       'name': 'Chantelle Barry',
#       'type': 'artist',
#       'uri': 'spotify:artist:4g3NvD4xvXlUW2iwqCIbiY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 205287,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEQS91701015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3DJnaK4ghuYyQiJAcq6PEN'},
#     'href': 'https://api.spotify.com/v1/tracks/3DJnaK4ghuYyQiJAcq6PEN',
#     'id': '3DJnaK4ghuYyQiJAcq6PEN',
#     'is_local': False,
#     'name': "Wolf's Heart (feat. Chantelle Barry)",
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4206a1f97130f0a9a9ab5f376d8da83e473f07c8?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3DJnaK4ghuYyQiJAcq6PEN'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ebS2RuCq8QeLyndUDmgB5'},
#        'href': 'https://api.spotify.com/v1/artists/3ebS2RuCq8QeLyndUDmgB5',
#        'id': '3ebS2RuCq8QeLyndUDmgB5',
#        'name': 'WizTheMc',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ebS2RuCq8QeLyndUDmgB5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3HwtxvL5vCqTmQdDNuEMm7'},
#      'href': 'https://api.spotify.com/v1/albums/3HwtxvL5vCqTmQdDNuEMm7',
#      'id': '3HwtxvL5vCqTmQdDNuEMm7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e23b6c91754cd7b9a79fd8f9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e23b6c91754cd7b9a79fd8f9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e23b6c91754cd7b9a79fd8f9',
#        'width': 64}],
#      'name': 'What About Now - EP',
#      'release_date': '2020-10-30',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:3HwtxvL5vCqTmQdDNuEMm7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ebS2RuCq8QeLyndUDmgB5'},
#       'href': 'https://api.spotify.com/v1/artists/3ebS2RuCq8QeLyndUDmgB5',
#       'id': '3ebS2RuCq8QeLyndUDmgB5',
#       'name': 'WizTheMc',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ebS2RuCq8QeLyndUDmgB5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1TBWWvhaT8b4ItnaIPrVNH'},
#       'href': 'https://api.spotify.com/v1/artists/1TBWWvhaT8b4ItnaIPrVNH',
#       'id': '1TBWWvhaT8b4ItnaIPrVNH',
#       'name': 'Wolfskind',
#       'type': 'artist',
#       'uri': 'spotify:artist:1TBWWvhaT8b4ItnaIPrVNH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 189814,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZJ842000686'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6BhYfYSCwvHVMov6EOzqwW'},
#     'href': 'https://api.spotify.com/v1/tracks/6BhYfYSCwvHVMov6EOzqwW',
#     'id': '6BhYfYSCwvHVMov6EOzqwW',
#     'is_local': False,
#     'name': 'Say Hi',
#     'popularity': 33,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:6BhYfYSCwvHVMov6EOzqwW'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7LVVFIS8cyyb9aM5OV3Im0'},
#        'href': 'https://api.spotify.com/v1/artists/7LVVFIS8cyyb9aM5OV3Im0',
#        'id': '7LVVFIS8cyyb9aM5OV3Im0',
#        'name': 'William Bilford',
#        'type': 'artist',
#        'uri': 'spotify:artist:7LVVFIS8cyyb9aM5OV3Im0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/33EnSk5EHcTVBMiycZ427c'},
#      'href': 'https://api.spotify.com/v1/albums/33EnSk5EHcTVBMiycZ427c',
#      'id': '33EnSk5EHcTVBMiycZ427c',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739a34e36eea0b5f5c586fabcc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029a34e36eea0b5f5c586fabcc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519a34e36eea0b5f5c586fabcc',
#        'width': 64}],
#      'name': "The Lone Wolf's Meadow",
#      'release_date': '2020-08-21',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:33EnSk5EHcTVBMiycZ427c'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7LVVFIS8cyyb9aM5OV3Im0'},
#       'href': 'https://api.spotify.com/v1/artists/7LVVFIS8cyyb9aM5OV3Im0',
#       'id': '7LVVFIS8cyyb9aM5OV3Im0',
#       'name': 'William Bilford',
#       'type': 'artist',
#       'uri': 'spotify:artist:7LVVFIS8cyyb9aM5OV3Im0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 127000,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32043801'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5085Fog6qVXvnsApSamQJl'},
#     'href': 'https://api.spotify.com/v1/tracks/5085Fog6qVXvnsApSamQJl',
#     'id': '5085Fog6qVXvnsApSamQJl',
#     'is_local': False,
#     'name': "The Lone Wolf's Meadow",
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d395eaffcad23ed7f3403ceb1e77b22cb0e4bca8?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5085Fog6qVXvnsApSamQJl'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7pTwf0aGXqupR7BjdmaVfM'},
#      'href': 'https://api.spotify.com/v1/albums/7pTwf0aGXqupR7BjdmaVfM',
#      'id': '7pTwf0aGXqupR7BjdmaVfM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fb9bd6738fb3c6050d3d26bb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fb9bd6738fb3c6050d3d26bb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fb9bd6738fb3c6050d3d26bb',
#        'width': 64}],
#      'name': "It's Complicated",
#      'release_date': '2020-09-18',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:7pTwf0aGXqupR7BjdmaVfM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1QdhlRYTvAbNbCe2x678yk'},
#       'href': 'https://api.spotify.com/v1/artists/1QdhlRYTvAbNbCe2x678yk',
#       'id': '1QdhlRYTvAbNbCe2x678yk',
#       'name': 'Sg Lily',
#       'type': 'artist',
#       'uri': 'spotify:artist:1QdhlRYTvAbNbCe2x678yk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5TzVqLypdQ0XDPxb4QtB6n'},
#       'href': 'https://api.spotify.com/v1/artists/5TzVqLypdQ0XDPxb4QtB6n',
#       'id': '5TzVqLypdQ0XDPxb4QtB6n',
#       'name': 'Swoopy',
#       'type': 'artist',
#       'uri': 'spotify:artist:5TzVqLypdQ0XDPxb4QtB6n'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/18WuC7ctSnVnsby2Px0aKK'},
#       'href': 'https://api.spotify.com/v1/artists/18WuC7ctSnVnsby2Px0aKK',
#       'id': '18WuC7ctSnVnsby2Px0aKK',
#       'name': 'Sg37',
#       'type': 'artist',
#       'uri': 'spotify:artist:18WuC7ctSnVnsby2Px0aKK'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
# ...
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2d3CnSj46oHCAIaxvtv1nn'},
#      'href': 'https://api.spotify.com/v1/albums/2d3CnSj46oHCAIaxvtv1nn',
#      'id': '2d3CnSj46oHCAIaxvtv1nn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e8e6e739864dea477c96138f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e8e6e739864dea477c96138f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e8e6e739864dea477c96138f',
#        'width': 64}],
#      'name': 'Are You Ready?',
#      'release_date': '2019-04-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2d3CnSj46oHCAIaxvtv1nn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bsnl8QpuYOt3UgAomFkeM'},
#       'href': 'https://api.spotify.com/v1/artists/5bsnl8QpuYOt3UgAomFkeM',
#       'id': '5bsnl8QpuYOt3UgAomFkeM',
#       'name': 'Wolfs',
#       'type': 'artist',
#       'uri': 'spotify:artist:5bsnl8QpuYOt3UgAomFkeM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 137040,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAEE1920480'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3erY87H4u86Pm0nHN6TfZq'},
#     'href': 'https://api.spotify.com/v1/tracks/3erY87H4u86Pm0nHN6TfZq',
#     'id': '3erY87H4u86Pm0nHN6TfZq',
#     'is_local': False,
#     'name': 'Are You Ready?',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/64dba7147dfd2d65cf347e73310c4c09ba532ece?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3erY87H4u86Pm0nHN6TfZq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0gm7i4kTY1zVrYFiiP7ehf'},
#        'href': 'https://api.spotify.com/v1/artists/0gm7i4kTY1zVrYFiiP7ehf',
#        'id': '0gm7i4kTY1zVrYFiiP7ehf',
#        'name': 'Presley Marsh',
#        'type': 'artist',
#        'uri': 'spotify:artist:0gm7i4kTY1zVrYFiiP7ehf'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1jHu42jQ3izZozSDE03jeA'},
#      'href': 'https://api.spotify.com/v1/albums/1jHu42jQ3izZozSDE03jeA',
#      'id': '1jHu42jQ3izZozSDE03jeA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737d78a5a8ec79029c44f79b90',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027d78a5a8ec79029c44f79b90',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517d78a5a8ec79029c44f79b90',
#        'width': 64}],
#      'name': 'Fragile',
#      'release_date': '2020-05-03',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1jHu42jQ3izZozSDE03jeA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0gm7i4kTY1zVrYFiiP7ehf'},
#       'href': 'https://api.spotify.com/v1/artists/0gm7i4kTY1zVrYFiiP7ehf',
#       'id': '0gm7i4kTY1zVrYFiiP7ehf',
#       'name': 'Presley Marsh',
#       'type': 'artist',
#       'uri': 'spotify:artist:0gm7i4kTY1zVrYFiiP7ehf'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 162501,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZL382029785'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/730O33kzBuJPVztL3RVO1P'},
#     'href': 'https://api.spotify.com/v1/tracks/730O33kzBuJPVztL3RVO1P',
#     'id': '730O33kzBuJPVztL3RVO1P',
#     'is_local': False,
#     'name': 'Wolfs',
#     'popularity': 19,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f0e47c8341acc1544b78fd01437e71452f809253?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:730O33kzBuJPVztL3RVO1P'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6L8qlm6sN9urvDB5ol7t5A'},
#        'href': 'https://api.spotify.com/v1/artists/6L8qlm6sN9urvDB5ol7t5A',
#        'id': '6L8qlm6sN9urvDB5ol7t5A',
#        'name': 'Onward To Olympas',
#        'type': 'artist',
#        'uri': 'spotify:artist:6L8qlm6sN9urvDB5ol7t5A'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5dDfUdEodW1g0o0DVvuTI7'},
#      'href': 'https://api.spotify.com/v1/albums/5dDfUdEodW1g0o0DVvuTI7',
#      'id': '5dDfUdEodW1g0o0DVvuTI7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27359f33b40e642558e718306c4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0259f33b40e642558e718306c4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485159f33b40e642558e718306c4',
#        'width': 64}],
#      'name': 'Indicator',
#      'release_date': '2012-10-09',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5dDfUdEodW1g0o0DVvuTI7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6L8qlm6sN9urvDB5ol7t5A'},
#       'href': 'https://api.spotify.com/v1/artists/6L8qlm6sN9urvDB5ol7t5A',
#       'id': '6L8qlm6sN9urvDB5ol7t5A',
#       'name': 'Onward To Olympas',
#       'type': 'artist',
#       'uri': 'spotify:artist:6L8qlm6sN9urvDB5ol7t5A'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 189146,
#     'explicit': False,
#     'external_ids': {'isrc': 'US38J1212203'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Hv3BomCozhJmgBo9TUOCQ'},
#     'href': 'https://api.spotify.com/v1/tracks/6Hv3BomCozhJmgBo9TUOCQ',
#     'id': '6Hv3BomCozhJmgBo9TUOCQ',
#     'is_local': False,
#     'name': "Wolf's Jaw",
#     'popularity': 18,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bec94d07214dcd60f8b64d529b762c8270a424be?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6Hv3BomCozhJmgBo9TUOCQ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/17bYSQ9ZRnreVnJjE5X2x6'},
#        'href': 'https://api.spotify.com/v1/artists/17bYSQ9ZRnreVnJjE5X2x6',
#        'id': '17bYSQ9ZRnreVnJjE5X2x6',
#        'name': 'Moonspell',
#        'type': 'artist',
#        'uri': 'spotify:artist:17bYSQ9ZRnreVnJjE5X2x6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1GnMnYl0I8CqgNSSODjwP7'},
#      'href': 'https://api.spotify.com/v1/albums/1GnMnYl0I8CqgNSSODjwP7',
#      'id': '1GnMnYl0I8CqgNSSODjwP7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b01cdea274dd654d0aabb17b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b01cdea274dd654d0aabb17b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b01cdea274dd654d0aabb17b',
#        'width': 64}],
#      'name': 'Wolfheart',
#      'release_date': '1995',
#      'release_date_precision': 'year',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:1GnMnYl0I8CqgNSSODjwP7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/17bYSQ9ZRnreVnJjE5X2x6'},
#       'href': 'https://api.spotify.com/v1/artists/17bYSQ9ZRnreVnJjE5X2x6',
#       'id': '17bYSQ9ZRnreVnJjE5X2x6',
#       'name': 'Moonspell',
#       'type': 'artist',
#       'uri': 'spotify:artist:17bYSQ9ZRnreVnJjE5X2x6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 463600,
#     'explicit': False,
#     'external_ids': {'isrc': 'US4E40479701'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/231iTjS7JBWWlDNQdfOijI'},
#     'href': 'https://api.spotify.com/v1/tracks/231iTjS7JBWWlDNQdfOijI',
#     'id': '231iTjS7JBWWlDNQdfOijI',
#     'is_local': False,
#     'name': 'Wolfshade (A Werewolf Masquerade)',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fb8ff15fdbc2888605827eac3859ed8519c4e172?cid=2fcf86918d5d434c90fe82b1294d12b0',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:231iTjS7JBWWlDNQdfOijI'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Wolfs&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 11936}}

# %%
spotify.get_artist('1cXi8ALPQCBHZbf0EgP4Ey')
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cXi8ALPQCBHZbf0EgP4Ey'},
#  'followers': {'href': None, 'total': 723378},
#  'genres': ['horror punk', 'new jersey hardcore', 'new jersey punk', 'punk'],
#  'href': 'https://api.spotify.com/v1/artists/1cXi8ALPQCBHZbf0EgP4Ey',
#  'id': '1cXi8ALPQCBHZbf0EgP4Ey',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/d21887c021ceb0288eb4ebd834b4af00085fd262',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/0c98e466f43756d272af522b047b4392f2966b00',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/9e790aa075fe228d0c3e2eb6433acb50fdc60ccb',
#    'width': 160}],
#  'name': 'Misfits',
#  'popularity': 69,
#  'type': 'artist',
#  'uri': 'spotify:artist:1cXi8ALPQCBHZbf0EgP4Ey'}
