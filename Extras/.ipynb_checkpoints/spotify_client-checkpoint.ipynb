# %%
# https://www.youtube.com/watch?v=xdq6Gz33khQ&ab_channel=CodingEntrepreneurs
# Coneccion a la API de Spotify
client_id = '2fcf86918d5d434c90fe82b1294d12b0'
client_secret = 'd7fa0a4a43fb4fff9cc3bce1940ff876'
user_id = '1279741536'

# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    client_id = None
    client_secret = None
    access_token_did_expire = True
    token_url = 'https://accounts.spotify.com/api/token'
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args,**kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    # Aqui se crean las credenciales en base 64 para poder acceder a la API
    def get_client_credentials(self):
        """ returns a base64 encoded string """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
            
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())        
        return client_creds_b64.decode()
    
    # Aqui estamos generando los headers de acceso
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        
        return {
            "Authorization":f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type":"client_credentials"
        }
    
    # Aqui nos autentificamos y obtenemos el token de acceso
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        
        r = requests.post(token_url, data = token_data, headers = token_headers)

        if r.status_code not in range(200,299):
            raise Exceptiontion('Could not authenticate client')
                  
        data = r.json()
        now = datetime.datetime.now()
        acces_token = data['access_token']
        expires_in = data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds = expires_in)
        self.access_token = acces_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    # Extraemos el token de acceso
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    # Aqui son los tokens de para las busquedas
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization":f"Bearer {access_token}"
        }
        return headers
        
    # busqueda de listas de reproduccion
    def get_user_playlist(self,u_id):
        endpoint = f'https://api.spotify.com/v1/users/{user_id}/playlists'
        headers = self.get_resource_header()
        r = requests.get(endpoint,headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def get_song_playlist(self,playlist_id):
        endpoint = f'https://api.spotify.com/v1/playlists/{playlist_id}/tracks'
        headers = self.get_resource_header()
        r = requests.get(endpoint,headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    # de Aqui en adelante son las busquedas que se requieren
    def get_resource(self,lookup_id,resource_type ='albums',version='v1'):
        endpoint = f'https://api.spotify.com/{version}/{resource_type}/{lookup_id}'
        headers = self.get_resource_header()
        r = requests.get(endpoint,headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type = 'albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type = 'artists')
    
    def base_search(self,query_params):
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        r = requests.get(lookup_url, headers = headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist' ):
        if query == None:
            raise Exception("A query is required")
        if isinstance(query, dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == "or" or operator.lower() == "not":
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q": query, "type": search_type.lower()})
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id,client_secret)

# %%
spotify.get_user_playlist(user_id)
# Out:
# {'href': 'https://api.spotify.com/v1/users/1279741536/playlists?offset=0&limit=20',
#  'items': [{'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4cneXKJlVKFLKAYuwtk57I'},
#    'href': 'https://api.spotify.com/v1/playlists/4cneXKJlVKFLKAYuwtk57I',
#    'id': '4cneXKJlVKFLKAYuwtk57I',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b273621489fd90d50158b3714cb0ab67616d0000b273627068a6288cf15faaa7e296ab67616d0000b273c4d00cac55ae1b4598c9bc90ab67616d0000b273d5929527336d3a19add3e036',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b273621489fd90d50158b3714cb0ab67616d0000b273627068a6288cf15faaa7e296ab67616d0000b273c4d00cac55ae1b4598c9bc90ab67616d0000b273d5929527336d3a19add3e036',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b273621489fd90d50158b3714cb0ab67616d0000b273627068a6288cf15faaa7e296ab67616d0000b273c4d00cac55ae1b4598c9bc90ab67616d0000b273d5929527336d3a19add3e036',
#      'width': 60}],
#    'name': 'Mis pistas en Shazam',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NSw3ZmY0OWU1NTY3YTE0MzM3OGFlYmRhMDU2NTEyZWQ3MzBmZDU4NzE4',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4cneXKJlVKFLKAYuwtk57I/tracks',
#     'total': 5},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4cneXKJlVKFLKAYuwtk57I'},
#   {'collaborative': False,
#    'description': 'Wobble, workout and blast off some heavy drops, filthy bass lines and trap elements in a mix of the best tracks and remixes!',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5wNRJwSnBImUuZXJW1TiAj'},
#    'href': 'https://api.spotify.com/v1/playlists/5wNRJwSnBImUuZXJW1TiAj',
#    'id': '5wNRJwSnBImUuZXJW1TiAj',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb188c686b200d4952fe2d7458',
#      'width': None}],
#    'name': 'Dubstep 2020\u200b\u200b   \u200d',
#    'owner': {'display_name': 'Filtr Sweden',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sonymusicentertainment'},
#     'href': 'https://api.spotify.com/v1/users/sonymusicentertainment',
#     'id': 'sonymusicentertainment',
#     'type': 'user',
#     'uri': 'spotify:user:sonymusicentertainment'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjAyMiwzZWI2NTljMDI3YzhmOTczMDM2OTM4MDFmMTcyYTk4NjYwMWZhOWNk',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5wNRJwSnBImUuZXJW1TiAj/tracks',
#     'total': 97},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5wNRJwSnBImUuZXJW1TiAj'},
#   {'collaborative': False,
#    'description': "Various sounds, various decades, but with 1 thing in common: it's pure rock & roll.",
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWWRktbhJiuqL'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWRktbhJiuqL',
#    'id': '37i9dQZF1DWWRktbhJiuqL',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000034eb58a097da59ad442e26bf2',
#      'width': None}],
#    'name': 'Pure Rock & Roll',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTYwNTY0NTkxNSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWRktbhJiuqL/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWWRktbhJiuqL'},
#   {'collaborative': False,
#    'description': '¡Los éxitos indie para levantar la fiesta!',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWSXAHZTiX76o'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSXAHZTiX76o',
#    'id': '37i9dQZF1DWSXAHZTiX76o',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003ceba7183bc05585045ae48ab',
#      'width': None}],
#    'name': 'Fiesta Indie',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTYwNTY0NTkxNSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSXAHZTiX76o/tracks',
#     'total': 50},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWSXAHZTiX76o'},
#   {'collaborative': False,
#    'description': 'Grandes temas del rock de ayer y de hoy.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1te6miphixI'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1te6miphixI',
#    'id': '37i9dQZF1DX1te6miphixI',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000034d6a1ff53ee321e85561e51b',
#      'width': None}],
#    'name': 'Radio Rock',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTYwNTY0NTkxNSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1te6miphixI/tracks',
#     'total': 50},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX1te6miphixI'},
#   {'collaborative': False,
#    'description': 'If you want to write good code, you need always to listen good music to do it, here is a recopliation of the songs that I used to listen. &#x2F;&#x2F; Si tu quieres escribir buen codigo, es necesario escuchar buena musica para hacerlo, esta es una recopilación de musica que suelo escuchar cuando lo hago.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1Yw7Hve6LoD46LlvfGI29T'},
#    'href': 'https://api.spotify.com/v1/playlists/1Yw7Hve6LoD46LlvfGI29T',
#    'id': '1Yw7Hve6LoD46LlvfGI29T',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b27346db3c1d529e0d7c0f7430ceab67616d0000b2734964b63a3b440fa58bb9d09eab67616d0000b2737676c7bf4e667590e496c2a3ab67616d0000b2739f2ee3f526327adefd970bc9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b27346db3c1d529e0d7c0f7430ceab67616d0000b2734964b63a3b440fa58bb9d09eab67616d0000b2737676c7bf4e667590e496c2a3ab67616d0000b2739f2ee3f526327adefd970bc9',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b27346db3c1d529e0d7c0f7430ceab67616d0000b2734964b63a3b440fa58bb9d09eab67616d0000b2737676c7bf4e667590e496c2a3ab67616d0000b2739f2ee3f526327adefd970bc9',
#      'width': 60}],
#    'name': 'Songs For Coding (Canciones para Programar)',
#    'owner': {'display_name': 'Luis Alberto Cisneros',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/luisaca'},
#     'href': 'https://api.spotify.com/v1/users/luisaca',
#     'id': 'luisaca',
#     'type': 'user',
#     'uri': 'spotify:user:luisaca'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NTk1LDQxOTgyYTAyMjA2NmI2NjVjMDU0YTIyNTI5ZWM3NjAwMGY5NDZjYTg=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1Yw7Hve6LoD46LlvfGI29T/tracks',
#     'total': 426},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1Yw7Hve6LoD46LlvfGI29T'},
#   {'collaborative': False,
#    'description': 'Enjoy the most epic, electrifying, face-melting axe performances.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWSlJG7YPUBHF'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSlJG7YPUBHF',
#    'id': '37i9dQZF1DWSlJG7YPUBHF',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000034884cb67656061753bec1452',
#      'width': None}],
#    'name': 'Legendary Guitar Solos',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTU2NzUwNDE0MywwMDAwMDAyMjAwMDAwMTY0NDI1YmVjMTkwMDAwMDE2Y2Y2ODcxNTU1',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSlJG7YPUBHF/tracks',
#     'total': 30},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWSlJG7YPUBHF'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4Za3xdOwf1rgsEuEgmgJbe'},
#    'href': 'https://api.spotify.com/v1/playlists/4Za3xdOwf1rgsEuEgmgJbe',
#    'id': '4Za3xdOwf1rgsEuEgmgJbe',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b273341ade4ea8bdc1e4fd59de1bab67616d0000b273806bd6155f9a3be9a8e8c6b1ab67616d0000b273a7e9888727cbee16899179dbab67616d0000b273ca13de8e1e9468cb8a21daa9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b273341ade4ea8bdc1e4fd59de1bab67616d0000b273806bd6155f9a3be9a8e8c6b1ab67616d0000b273a7e9888727cbee16899179dbab67616d0000b273ca13de8e1e9468cb8a21daa9',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b273341ade4ea8bdc1e4fd59de1bab67616d0000b273806bd6155f9a3be9a8e8c6b1ab67616d0000b273a7e9888727cbee16899179dbab67616d0000b273ca13de8e1e9468cb8a21daa9',
#      'width': 60}],
#    'name': 'Mis pistas de Shazam',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NywzNTMwOGVkNGEzZTNmNDJiMDY3ZmVjNjM5MTQ4ZTE0YTVjMjg0MDg1',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4Za3xdOwf1rgsEuEgmgJbe/tracks',
#     'total': 6},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4Za3xdOwf1rgsEuEgmgJbe'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1Hh3HB9DCsUBI65xAq6CUG'},
#    'href': 'https://api.spotify.com/v1/playlists/1Hh3HB9DCsUBI65xAq6CUG',
#    'id': '1Hh3HB9DCsUBI65xAq6CUG',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b27309b25cc58c748bd5a0ea9e9dab67616d0000b27312902a5668aa14a335d0d529ab67616d0000b2733d8681f44a7ce5ad52de85cdab67616d0000b273c46f187074b3f76b2a969a8a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b27309b25cc58c748bd5a0ea9e9dab67616d0000b27312902a5668aa14a335d0d529ab67616d0000b2733d8681f44a7ce5ad52de85cdab67616d0000b273c46f187074b3f76b2a969a8a',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b27309b25cc58c748bd5a0ea9e9dab67616d0000b27312902a5668aa14a335d0d529ab67616d0000b2733d8681f44a7ce5ad52de85cdab67616d0000b273c46f187074b3f76b2a969a8a',
#      'width': 60}],
#    'name': 'Nacha Pop – Universal.es.Nacha Pop (Edited Version)',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MywyYjYwYzcwODQ3ODUxYzAzMGRiZWZkMGJhOTYxZTgwMzIzNTZmZWJm',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1Hh3HB9DCsUBI65xAq6CUG/tracks',
#     'total': 38},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1Hh3HB9DCsUBI65xAq6CUG'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7nvh5grWo61NRk9ex0BucP'},
#    'href': 'https://api.spotify.com/v1/playlists/7nvh5grWo61NRk9ex0BucP',
#    'id': '7nvh5grWo61NRk9ex0BucP',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b27309b25cc58c748bd5a0ea9e9dab67616d0000b2733d8681f44a7ce5ad52de85cdab67616d0000b273864ac0c0f1a89ecf82737cebab67616d0000b273adf8c35b4a1e061bff0e09b1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b27309b25cc58c748bd5a0ea9e9dab67616d0000b2733d8681f44a7ce5ad52de85cdab67616d0000b273864ac0c0f1a89ecf82737cebab67616d0000b273adf8c35b4a1e061bff0e09b1',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b27309b25cc58c748bd5a0ea9e9dab67616d0000b2733d8681f44a7ce5ad52de85cdab67616d0000b273864ac0c0f1a89ecf82737cebab67616d0000b273adf8c35b4a1e061bff0e09b1',
#      'width': 60}],
#    'name': 'Nacha Pop – La Más Completa Colección',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Myw3NWU5OTgyN2M2NmEyM2FmNjBkYzBmOTE2Y2M4YjkxZGQ5NzFiNzdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7nvh5grWo61NRk9ex0BucP/tracks',
#     'total': 25},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7nvh5grWo61NRk9ex0BucP'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6ywZrlkvzUHogLtjnZhRIx'},
#    'href': 'https://api.spotify.com/v1/playlists/6ywZrlkvzUHogLtjnZhRIx',
#    'id': '6ywZrlkvzUHogLtjnZhRIx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a5895b4e7aed6169f84810e1',
#      'width': 640}],
#    'name': 'Nacha Pop – Nacha Pop',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Myw2OTgzZTkxZmU3ZGViNDU0MWI3ODZiOTY5NzgxYjUxMjZmNTZkOWUx',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6ywZrlkvzUHogLtjnZhRIx/tracks',
#     'total': 12},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6ywZrlkvzUHogLtjnZhRIx'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2O7wV2QZi7QYpQYsY38iqQ'},
#    'href': 'https://api.spotify.com/v1/playlists/2O7wV2QZi7QYpQYsY38iqQ',
#    'id': '2O7wV2QZi7QYpQYsY38iqQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f9a4efda92c7cf9711a90384',
#      'width': 640}],
#    'name': 'Nacha Pop – Buena Disposicion',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Myw0YmNkMDUyNjg5MWVkMTBiYTljNzdjMmQzZDY2NmE1ZmI2OWEwN2Rk',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2O7wV2QZi7QYpQYsY38iqQ/tracks',
#     'total': 13},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2O7wV2QZi7QYpQYsY38iqQ'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4XPbfflCExJlMyI2pCJDDE'},
#    'href': 'https://api.spotify.com/v1/playlists/4XPbfflCExJlMyI2pCJDDE',
#    'id': '4XPbfflCExJlMyI2pCJDDE',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738996c3697ec3030efbd0a04f',
#      'width': 640}],
#    'name': 'Duncan Dhu – Canciones',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Myw2MzQwNDA2MmVlOTQ4MjNiNDhkMGQxMjNmMjU0Y2RmZWFhMzNhZTQ2',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4XPbfflCExJlMyI2pCJDDE/tracks',
#     'total': 12},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4XPbfflCExJlMyI2pCJDDE'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4r1YGed9XCLyswnoN7Tkfw'},
#    'href': 'https://api.spotify.com/v1/playlists/4r1YGed9XCLyswnoN7Tkfw',
#    'id': '4r1YGed9XCLyswnoN7Tkfw',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f644dfcec2d35ebc60bc427b',
#      'width': 640}],
#    'name': 'Duncan Dhu – Grabaciones Olvidadas',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MyxlMzFkNjNmYWRhZmE2NWM3MjVkMDk5NDlhOTVjZDFiYWQzNjM1OWJk',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4r1YGed9XCLyswnoN7Tkfw/tracks',
#     'total': 17},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4r1YGed9XCLyswnoN7Tkfw'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7HiRRIaFkfWo3DWNFPAgJW'},
#    'href': 'https://api.spotify.com/v1/playlists/7HiRRIaFkfWo3DWNFPAgJW',
#    'id': '7HiRRIaFkfWo3DWNFPAgJW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273cecc55a490d0f56137c9e6e8',
#      'width': 640}],
#    'name': 'Duncan Dhu – Autobiografia',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MyxhMGY5ZmNjZjE3ZTAwMmQ5MzVkZjRkNGQ1Y2QzMjhhYTQxNTkyZjMx',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7HiRRIaFkfWo3DWNFPAgJW/tracks',
#     'total': 30},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7HiRRIaFkfWo3DWNFPAgJW'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5V0kFrendJQd01IKbO1mE8'},
#    'href': 'https://api.spotify.com/v1/playlists/5V0kFrendJQd01IKbO1mE8',
#    'id': '5V0kFrendJQd01IKbO1mE8',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27321472fa0fabe421c68c19561',
#      'width': 640}],
#    'name': 'Duncan Dhu – Supernova',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MywxMTQ3OWI2MmVhNDAwMWI3MjZhOGZjMWRmZGY3MmFhMGZiYTVhNzM0',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5V0kFrendJQd01IKbO1mE8/tracks',
#     'total': 11},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5V0kFrendJQd01IKbO1mE8'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0YLFOj30e376NQoGa3oGI3'},
#    'href': 'https://api.spotify.com/v1/playlists/0YLFOj30e376NQoGa3oGI3',
#    'id': '0YLFOj30e376NQoGa3oGI3',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a35f79eb165416194fd0aacf',
#      'width': 640}],
#    'name': 'Duncan Dhu – Piedras',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Myw4NzAxYmE2OWE1NWYyZWRiY2M4ZDc2MDFhOWYyNjE0NjRkOTgyMDEz',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0YLFOj30e376NQoGa3oGI3/tracks',
#     'total': 11},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0YLFOj30e376NQoGa3oGI3'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1gLQQGj3Ag4AslTOBitxlF'},
#    'href': 'https://api.spotify.com/v1/playlists/1gLQQGj3Ag4AslTOBitxlF',
#    'id': '1gLQQGj3Ag4AslTOBitxlF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273801dd4ac161b4f2c4b4c046b',
#      'width': 640}],
#    'name': 'Duncan Dhu – Teatro Victoria Eugenia',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Myw5OWQzZGUxOTZmNmJmNmNkZmVkZTY1MGJkN2ZiZjczYTM1NGYzMDg3',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1gLQQGj3Ag4AslTOBitxlF/tracks',
#     'total': 19},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1gLQQGj3Ag4AslTOBitxlF'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5FHSeEgQjspGl6QJeyNTho'},
#    'href': 'https://api.spotify.com/v1/playlists/5FHSeEgQjspGl6QJeyNTho',
#    'id': '5FHSeEgQjspGl6QJeyNTho',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a4b46c9ca1b602ef5df37884',
#      'width': 640}],
#    'name': 'Duncan Dhu – El Grito Del Tiempo',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Myw4NzZhYWVhMGZmOTkyNTk1NjA0MzhjZDA0MWE1OTBjMzExMDMwMDY0',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5FHSeEgQjspGl6QJeyNTho/tracks',
#     'total': 16},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5FHSeEgQjspGl6QJeyNTho'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5uOZ4NdrmGuOOF2JCCdpKB'},
#    'href': 'https://api.spotify.com/v1/playlists/5uOZ4NdrmGuOOF2JCCdpKB',
#    'id': '5uOZ4NdrmGuOOF2JCCdpKB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d603229a76309d47f4c606e4',
#      'width': 640}],
#    'name': 'Duncan Dhu – Coleccion 1985-1998',
#    'owner': {'display_name': 'Ricardo Fuentes',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1279741536'},
#     'href': 'https://api.spotify.com/v1/users/1279741536',
#     'id': '1279741536',
#     'type': 'user',
#     'uri': 'spotify:user:1279741536'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MywxZTYxZTEyMWU2ODljYmM4NDNhNGI0ODE0NGFiYTFkOTc1OTY5Yjhi',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5uOZ4NdrmGuOOF2JCCdpKB/tracks',
#     'total': 40},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5uOZ4NdrmGuOOF2JCCdpKB'}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/users/1279741536/playlists?offset=20&limit=20',
#  'offset': 0,
#  'previous': None,
#  'total': 243}

# %%
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}
