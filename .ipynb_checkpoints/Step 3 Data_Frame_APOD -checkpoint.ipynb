# %%
import pandas as pd

# %%
data_web=pd.read_csv('Web_scraping_nasa_apod_urls_.csv')
data_api=pd.read_csv('Api_nasa_apod_information.csv')

# %%
#Verificar cada data frame y eliminar columnas inecesarias en data_web
data_web
# Out:
#       Unnamed: 0                0  \
# 0              0  2015 January 01
# 1              1  2015 January 02
# 2              2  2015 January 03
# 3              3  2015 January 04
# 4              4  2015 January 05
# ...          ...              ...
# 1955        1955      2020 May 09
# 1956        1956      2020 May 10
# 1957        1957      2020 May 11
# 1958        1958      2020 May 12
# 1959        1959      2020 May 13
#
#                                                  1  \
# 0                           Vela Supernova Remnant
# 1                            At the Heart of Orion
# 2                                        Apollo 17
# 3            Crescent Rhea Occults Crescent Saturn
# 4       A Fox Fur, a Unicorn, and a Christmas Tree
# ...                                            ...
# 1955                          Full Flower Moonrise
# 1956               The Porpoise Galaxy from Hubble
# 1957                             Behind Betelgeuse
# ...

# %%
del(data_web['Unnamed: 0'])
data_web
# Out:
#                     0                                             1  \
# 0     2015 January 01                        Vela Supernova Remnant
# 1     2015 January 02                         At the Heart of Orion
# 2     2015 January 03                                     Apollo 17
# 3     2015 January 04         Crescent Rhea Occults Crescent Saturn
# 4     2015 January 05    A Fox Fur, a Unicorn, and a Christmas Tree
# ...               ...                                           ...
# 1955      2020 May 09                          Full Flower Moonrise
# 1956      2020 May 10               The Porpoise Galaxy from Hubble
# 1957      2020 May 11                             Behind Betelgeuse
# 1958      2020 May 12     Lyrid Meteors from the Constellation Lyra
# 1959      2020 May 13               Jupiter in Infrared from Gemini
#
#                                            0.1
# 0     https://apod.nasa.gov/apod/ap150101.html
# 1     https://apod.nasa.gov/apod/ap150102.html
# ...

# %%
#Verificar cada data frame y eliminar columnas inecesarias en data_api
data_api
# Out:
#       Unnamed: 0                                          copyright  \
# 0              0                                         CEDIC Team
# 1              1                                   László Francsics
# 2              2                                                NaN
# 3              3                                                NaN
# 4              4    R. ColombariFrancesco Antonucci Data: SubaruESO
# ...          ...                                                ...
# 1955        1955                                   Tiziano Boldrini
# 1956        1956                                    Raul Villaverde
# 1957        1957  Adam BlockSteward Observatory,\nUniversity of ...
# 1958        1958                                       Petr Horálek
# 1959        1959                                                NaN
#
#             date                                        explanation  \
# 0     2015-01-01  The plane of our Milky Way Galaxy runs through...
# ...

# %%
del(data_api['Unnamed: 0'])
data_api
# Out:
#                                               copyright        date  \
# 0                                            CEDIC Team  2015-01-01
# 1                                      László Francsics  2015-01-02
# 2                                                   NaN  2015-01-03
# 3                                                   NaN  2015-01-04
# 4       R. ColombariFrancesco Antonucci Data: SubaruESO  2015-01-05
# ...                                                 ...         ...
# 1955                                   Tiziano Boldrini  2020-05-09
# 1956                                    Raul Villaverde  2020-05-10
# 1957  Adam BlockSteward Observatory,\nUniversity of ...  2020-05-11
# 1958                                       Petr Horálek  2020-05-12
# 1959                                                NaN  2020-05-13
#
#                                             explanation  \
# 0     The plane of our Milky Way Galaxy runs through...
# ...

# %%
#Concatenar df desde el indice y eliminar columnas repetidas

df_info=pd.concat([data_api,data_web],axis=1)
df_info
# Out:
#                                               copyright        date  \
# 0                                            CEDIC Team  2015-01-01
# 1                                      László Francsics  2015-01-02
# 2                                                   NaN  2015-01-03
# 3                                                   NaN  2015-01-04
# 4       R. ColombariFrancesco Antonucci Data: SubaruESO  2015-01-05
# ...                                                 ...         ...
# 1955                                   Tiziano Boldrini  2020-05-09
# 1956                                    Raul Villaverde  2020-05-10
# 1957  Adam BlockSteward Observatory,\nUniversity of ...  2020-05-11
# 1958                                       Petr Horálek  2020-05-12
# 1959                                                NaN  2020-05-13
#
#                                             explanation  \
# 0     The plane of our Milky Way Galaxy runs through...
# ...
