# %% [markdown]
# #### Crypto, Stocks and Markets extraction

# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import datetime
from pprint import pprint
import matplotlib.pyplot as plt
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import asyncio
from alpha_vantage.async_support.timeseries import TimeSeries
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

# %%
#pip install alpha_vantage
# Out:
# Collecting alpha_vantage
#   Downloading alpha_vantage-2.2.0.tar.gz (20 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.6.2-cp37-cp37m-win32.whl (624 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from alpha_vantage) (2.22.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (19.3.0)
# Collecting multidict<5.0,>=4.5
#   Downloading multidict-4.7.5-cp37-cp37m-win32.whl (46 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.4.2-cp37-cp37m-win32.whl (119 kB)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: chardet<4.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->alpha_vantage) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->alpha_vantage) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->alpha_vantage) (2.8)
# Building wheels for collected packages: alpha-vantage
#   Building wheel for alpha-vantage (setup.py): started
#   Building wheel for alpha-vantage (setup.py): finished with status 'done'
#   Created wheel for alpha-vantage: filename=alpha_vantage-2.2.0-py3-none-any.whl size=25708 sha256=bed765688f48cee9970c85b5c7d860152d645f163f3e0676d2eda3a40e0db690
#   Stored in directory: c:\users\joavi\appdata\local\pip\cache\wheels\ee\38\2e\306b4a5a2d645520be01077accdd067b9e419006083038ef7e
# Successfully built alpha-vantage
# Installing collected packages: multidict, yarl, async-timeout, aiohttp, alpha-vantage
# Successfully installed aiohttp-3.6.2 alpha-vantage-2.2.0 async-timeout-3.0.1 multidict-4.7.5 yarl-1.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
ts_MSFT = TimeSeries(key='<key>', output_format='pandas')
s_MSFT = ts_MSFT.get_daily_adjusted(symbol='MSFT', outputsize='full')
print(s_MSFT)

#url = "https://alpha-vantage.p.rapidapi.com/query"
#querystring = {"outputsize":"compact","datatype":"json","function":"TIME_SERIES_DAILY_ADJUSTED","symbol":"TSLA"}
#headers = {
#    'x-rapidapi-host': "alpha-vantage.p.rapidapi.com",
#    'x-rapidapi-key': "<key>"
#    }
#response = requests.request("GET", url, headers=headers, params=querystring)
#stocksdf = pd.DataFrame(response)
#print(stocksdf)
# Out:
# (             1. open  2. high    3. low  4. close  5. adjusted close  \
# date
# 2020-05-12  186.9000   187.04  182.3000    182.51           182.5100
# 2020-05-11  183.1500   187.51  182.8500    186.74           186.7400
# 2020-05-08  184.9797   185.00  183.3600    184.68           184.6800
# 2020-05-07  184.1700   184.55  182.5800    183.60           183.6000
# 2020-05-06  182.0800   184.20  181.6306    182.54           182.5400
# ...              ...      ...       ...       ...                ...
# 2000-05-17   68.8700    69.12   67.2500     67.69            21.7625
# 2000-05-16   69.5600    70.62   69.0600     69.50            22.3445
# 2000-05-15   69.0000    69.44   68.0000     69.37            22.3027
# 2000-05-12   68.4400    69.75   68.2500     68.81            22.1226
# 2000-05-11   66.6200    68.12   65.7500     67.87            21.8204
#
#              6. volume  7. dividend amount  8. split coefficient
# date
# 2020-05-12  31673903.0                 0.0                   1.0
# 2020-05-11  30892660.0                 0.0                   1.0
# 2020-05-08  30912638.0                 0.0                   1.0
# 2020-05-07  28315992.0                 0.0                   1.0
# 2020-05-06  32139299.0                 0.0                   1.0
# ...                ...                 ...                   ...
# 2000-05-17  26621000.0                 0.0                   1.0
# 2000-05-16  24205300.0                 0.0                   1.0
# 2000-05-15  16949800.0                 0.0                   1.0
# 2000-05-12  18943000.0                 0.0                   1.0
# 2000-05-11  29195400.0                 0.0                   1.0
#
# [5032 rows x 8 columns],
#  {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'MSFT',
#   '3. Last Refreshed': '2020-05-12',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'})

# %%
ts_TSLA = TimeSeries(key='<key>', output_format='pandas')
s_TSLA = ts_TSLA.get_daily_adjusted(symbol='TSLA', outputsize='full')
print(s_TSLA)
# Out:
# (            1. open   2. high  3. low  4. close  5. adjusted close  \
# date
# 2020-05-12   827.00  843.2900  808.00    809.41             809.41
# 2020-05-11   790.51  824.0000  785.00    811.29             811.29
# 2020-05-08   793.77  824.0000  787.01    819.42             819.42
# 2020-05-07   777.21  796.4000  772.35    780.04             780.04
# 2020-05-06   776.50  789.8000  761.11    782.58             782.58
# ...             ...       ...     ...       ...                ...
# 2010-07-06    20.00   20.0000   15.83     16.11              16.11
# 2010-07-02    23.00   23.1000   18.71     19.20              19.20
# 2010-07-01    25.00   25.9200   20.27     21.96              21.96
# 2010-06-30    25.79   30.4192   23.30     23.83              23.83
# 2010-06-29    19.00   25.0000   17.54     23.89              23.89
#
#              6. volume  7. dividend amount  8. split coefficient
# date
# 2020-05-12  15671509.0                 0.0                   1.0
# 2020-05-11  16519601.0                 0.0                   1.0
# 2020-05-08  16130087.0                 0.0                   1.0
# 2020-05-07  11527686.0                 0.0                   1.0
# 2020-05-06  11123231.0                 0.0                   1.0
# ...                ...                 ...                   ...
# 2010-07-06   6866900.0                 0.0                   1.0
# 2010-07-02   5139800.0                 0.0                   1.0
# 2010-07-01   8218800.0                 0.0                   1.0
# 2010-06-30  17187100.0                 0.0                   1.0
# 2010-06-29  18766300.0                 0.0                   1.0
#
# [2485 rows x 8 columns], {'1. Information': 'Daily Time Series with Splits and Dividend Events', '2. Symbol': 'TSLA', '3. Last Refreshed': '2020-05-12', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'})

# %%
ts_AMZN = TimeSeries(key='<key>', output_format='pandas')
s_AMZN = ts_AMZN.get_daily_adjusted(symbol='AMZN', outputsize='full')
print(s_AMZN)
# Out:
# (            1. open  2. high   3. low  4. close  5. adjusted close  6. volume  \
# date
# 2020-05-12  2411.85  2419.00  2355.00   2356.95            2356.95  3013922.0
# 2020-05-11  2374.70  2419.66  2372.11   2409.00            2409.00  3259231.0
# 2020-05-08  2372.14  2387.24  2357.00   2379.61            2379.61  3211228.0
# 2020-05-07  2374.78  2376.00  2343.11   2367.61            2367.61  3396411.0
# 2020-05-06  2329.44  2357.45  2320.00   2351.26            2351.26  3117814.0
# ...             ...      ...      ...       ...                ...        ...
# 2000-05-17    57.19    62.38    57.00     61.00              61.00  6998600.0
# 2000-05-16    57.13    59.88    56.00     59.06              59.06  6432200.0
# 2000-05-15    53.63    56.50    50.88     56.06              56.06  4125400.0
# 2000-05-12    54.69    56.50    53.13     53.75              53.75  3969600.0
# 2000-05-11    53.94    55.75    50.94     54.88              54.88  5580800.0
#
#             7. dividend amount  8. split coefficient
# date
# 2020-05-12                 0.0                   1.0
# 2020-05-11                 0.0                   1.0
# 2020-05-08                 0.0                   1.0
# 2020-05-07                 0.0                   1.0
# 2020-05-06                 0.0                   1.0
# ...                        ...                   ...
# 2000-05-17                 0.0                   1.0
# 2000-05-16                 0.0                   1.0
# 2000-05-15                 0.0                   1.0
# 2000-05-12                 0.0                   1.0
# 2000-05-11                 0.0                   1.0
#
# [5032 rows x 8 columns], {'1. Information': 'Daily Time Series with Splits and Dividend Events', '2. Symbol': 'AMZN', '3. Last Refreshed': '2020-05-12', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'})

# %%
ts_AAPL = TimeSeries(key='<key>', output_format='pandas')
s_AAPL = ts_AAPL.get_daily_adjusted(symbol='AAPL', outputsize='full')
print(s_AAPL)
# Out:
# (            1. open  2. high  3. low  4. close  5. adjusted close   6. volume  \
# date
# 2020-05-12   317.83  319.688  310.91    311.41           311.4100  39716963.0
# 2020-05-11   308.10  317.050  307.24    315.01           315.0100  36486561.0
# 2020-05-08   305.64  310.350  304.29    310.13           310.1300  33511985.0
# 2020-05-07   303.22  305.170  301.97    303.74           302.9390  28803764.0
# 2020-05-06   300.46  303.240  298.87    300.63           299.8372  35583438.0
# ...             ...      ...     ...       ...                ...         ...
# 2000-05-17   103.62  103.690  100.37    101.37             3.1339   3554400.0
# 2000-05-16   104.52  109.060  102.75    105.69             3.2674   3932600.0
# 2000-05-15   108.06  108.060  100.12    101.00             3.1224   6061900.0
# 2000-05-12   106.00  110.500  104.77    107.62             3.3271   2740300.0
# 2000-05-11   101.37  104.250   99.00    102.81             3.1784   4462000.0
#
#             7. dividend amount  8. split coefficient
# date
# 2020-05-12                0.00                   1.0
# 2020-05-11                0.00                   1.0
# 2020-05-08                0.82                   1.0
# 2020-05-07                0.00                   1.0
# 2020-05-06                0.00                   1.0
# ...                        ...                   ...
# 2000-05-17                0.00                   1.0
# 2000-05-16                0.00                   1.0
# 2000-05-15                0.00                   1.0
# 2000-05-12                0.00                   1.0
# 2000-05-11                0.00                   1.0
#
# [5032 rows x 8 columns], {'1. Information': 'Daily Time Series with Splits and Dividend Events', '2. Symbol': 'AAPL', '3. Last Refreshed': '2020-05-12', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'})

# %%
ts_GOOG = TimeSeries(key='<key>', output_format='pandas')
s_GOOG = ts_GOOG.get_daily_adjusted(symbol='GOOG', outputsize='full')
print(s_GOOG)
# Out:
# (             1. open  2. high   3. low  4. close  5. adjusted close  \
# date
# 2020-05-12  1407.120  1415.00  1374.77   1375.74            1375.74
# 2020-05-11  1378.280  1416.53  1377.15   1403.26            1403.26
# 2020-05-08  1383.130  1398.76  1375.48   1388.37            1388.37
# 2020-05-07  1365.940  1377.60  1355.27   1372.56            1372.56
# 2020-05-06  1361.690  1371.12  1347.29   1347.30            1347.30
# ...              ...      ...      ...       ...                ...
# 2014-04-02   565.106   604.83   562.19    567.00             567.00
# 2014-04-01   558.710   568.45   558.71    567.16             567.16
# 2014-03-31   566.890   567.00   556.93    556.97             556.97
# 2014-03-28   561.200   566.43   558.67    559.99             559.99
# 2014-03-27   568.000   568.00   552.92    558.46             558.46
#
#             6. volume  7. dividend amount  8. split coefficient
# date
# 2020-05-12  1382998.0                 0.0                   1.0
# 2020-05-11  1412116.0                 0.0                   1.0
# 2020-05-08  1388068.0                 0.0                   1.0
# 2020-05-07  1399759.0                 0.0                   1.0
# 2020-05-06  1215423.0                 0.0                   1.0
# ...               ...                 ...                   ...
# 2014-04-02   146700.0                 0.0                   1.0
# 2014-04-01     7900.0                 0.0                   1.0
# 2014-03-31    10800.0                 0.0                   1.0
# 2014-03-28    41100.0                 0.0                   1.0
# 2014-03-27    13100.0                 0.0                   1.0
#
# [1543 rows x 8 columns], {'1. Information': 'Daily Time Series with Splits and Dividend Events', '2. Symbol': 'GOOG', '3. Last Refreshed': '2020-05-12', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'})

# %%
ts_FB = TimeSeries(key='<key>', output_format='pandas')
s_FB = ts_FB.get_daily_adjusted(symbol='FB', outputsize='full')
print(s_FB)
# Out:
# (             1. open  2. high  3. low  4. close  5. adjusted close  \
# date
# 2020-05-12  213.2900  215.275  210.00  210.1000           210.1000
# 2020-05-11  210.8865  215.000  210.37  213.1800           213.1800
# 2020-05-08  212.2400  213.210  210.85  212.3500           212.3500
# 2020-05-07  211.1600  211.600  209.04  211.2600           211.2600
# 2020-05-06  208.1200  211.600  206.66  208.4700           208.4700
# ...              ...      ...     ...       ...                ...
# 2012-05-24   32.9500   33.210   31.77   33.0300            33.0300
# 2012-05-23   31.3700   32.500   31.36   32.0000            32.0000
# 2012-05-22   32.6100   33.590   30.94   31.0000            31.0000
# 2012-05-21   36.5300   36.660   33.00   34.0300            34.0300
# 2012-05-18   42.0500   45.000   38.00   38.2318            38.2318
#
#               6. volume  7. dividend amount  8. split coefficient
# date
# 2020-05-12   14536181.0                 0.0                   1.0
# 2020-05-11   12911948.0                 0.0                   1.0
# 2020-05-08   12524048.0                 0.0                   1.0
# 2020-05-07   15151976.0                 0.0                   1.0
# 2020-05-06   21856963.0                 0.0                   1.0
# ...                 ...                 ...                   ...
# 2012-05-24   50237200.0                 0.0                   1.0
# 2012-05-23   73600000.0                 0.0                   1.0
# 2012-05-22  101786600.0                 0.0                   1.0
# 2012-05-21  168192700.0                 0.0                   1.0
# 2012-05-18  573576400.0                 0.0                   1.0
#
# [2008 rows x 8 columns], {'1. Information': 'Daily Time Series with Splits and Dividend Events', '2. Symbol': 'FB', '3. Last Refreshed': '2020-05-12', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'})

# %%
s_df=pd.DataFrame()
s_df[s_AAPL[1]['2. Symbol']]=s_AAPL[0]['4. close']
s_df[s_FB[1]['2. Symbol']]=s_FB[0]['4. close']
s_df[s_AMZN[1]['2. Symbol']]=s_AMZN[0]['4. close']
s_df[s_MSFT[1]['2. Symbol']]=s_MSFT[0]['4. close']
s_df[s_GOOG[1]['2. Symbol']]=s_GOOG[0]['4. close']
s_df[s_TSLA[1]['2. Symbol']]=s_TSLA[0]['4. close']
print(s_df)
# Out:
#               AAPL      FB     AMZN    MSFT     GOOG    TSLA
# date
# 2020-05-12  311.41  210.10  2356.95  182.51  1375.74  809.41
# 2020-05-11  315.01  213.18  2409.00  186.74  1403.26  811.29
# 2020-05-08  310.13  212.35  2379.61  184.68  1388.37  819.42
# 2020-05-07  303.74  211.26  2367.61  183.60  1372.56  780.04
# 2020-05-06  300.63  208.47  2351.26  182.54  1347.30  782.58
# ...            ...     ...      ...     ...      ...     ...
# 2000-05-17  101.37     NaN    61.00   67.69      NaN     NaN
# 2000-05-16  105.69     NaN    59.06   69.50      NaN     NaN
# 2000-05-15  101.00     NaN    56.06   69.37      NaN     NaN
# 2000-05-12  107.62     NaN    53.75   68.81      NaN     NaN
# 2000-05-11  102.81     NaN    54.88   67.87      NaN     NaN
#
# [5032 rows x 6 columns]

# %%
s_df.index = pd.to_datetime(s_df.index)
s_df.plot()

datein = '2000-01-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.title('Big Tech Stocks')
plt.xlim([date_in.date(),date_out.date()])
plt.show()

# %%
s_df.plot()

datein = '2017-07-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.title('Big Tech Stocks')
plt.xlim([date_in.date(),date_out.date()])
plt.show()

# %%
ts = TimeSeries(key='<key>', output_format='pandas')
sb_JPM = ts.get_daily_adjusted(symbol='JPM', outputsize='full')
sb_BAC = ts.get_daily_adjusted(symbol='BAC', outputsize='full')
sb_WFC = ts.get_daily_adjusted(symbol='WFC', outputsize='full')

# %%
sb_C = ts.get_daily_adjusted(symbol='C', outputsize='full')
sb_GR = ts.get_daily_adjusted(symbol='GS', outputsize='full')

# %%
sb_df=pd.DataFrame()
sb_df[sb_JPM[1]['2. Symbol']]=sb_JPM[0]['4. close']
sb_df[sb_BAC[1]['2. Symbol']]=sb_BAC[0]['4. close']
sb_df[sb_WFC[1]['2. Symbol']]=sb_WFC[0]['4. close']
sb_df[sb_C[1]['2. Symbol']]=sb_C[0]['4. close']
sb_df[sb_GR[1]['2. Symbol']]=sb_GR[0]['4. close']
print(sb_df)
# Out:
#               JPM    BAC    WFC      C      GS
# date
# 2020-05-12  87.03  21.87  24.04  42.35  177.21
# 2020-05-11  89.97  22.58  24.78  44.07  183.16
# 2020-05-08  92.70  23.57  25.43  46.32  185.39
# 2020-05-07  91.21  22.84  25.23  44.64  182.32
# 2020-05-06  90.27  22.35  25.61  42.95  176.92
# ...           ...    ...    ...    ...     ...
# 2000-05-17  74.00  49.31  42.94  61.06   84.69
# 2000-05-16  74.25  49.69  43.63  61.69   85.50
# 2000-05-15  74.62  50.63  44.88  62.88   87.06
# 2000-05-12  71.62  48.59  43.69  60.19   83.77
# 2000-05-11  70.00  47.38  42.50  58.88   80.88
#
# [5032 rows x 5 columns]

# %%
sb_df.index = pd.to_datetime(sb_df.index)
sb_df.plot()


datein = '2000-01-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.xlim([date_in.date(),date_out.date()])
plt.title('Big Banks Stocks')
plt.show()

# %%
sb_df.plot()

datein = '2017-07-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.xlim([date_in.date(),date_out.date()])
plt.title('Big Banks Stocks')
plt.show()

# %%
url = "https://alpha-vantage.p.rapidapi.com/query"
querystring = {"market":"USD","symbol":"BTC","function":"DIGITAL_CURRENCY_DAILY","output_format":"pandas"}
headers = {
    'x-rapidapi-host': "alpha-vantage.p.rapidapi.com",
    'x-rapidapi-key': "<key>"
    }
ct_btc = requests.request("GET", url, headers=headers, params=querystring)
#print(ct_btc.text)

#<key>

# %%
url = "https://alpha-vantage.p.rapidapi.com/query"
querystring = {"market":"USD","symbol":"ETC","function":"DIGITAL_CURRENCY_DAILY","output_format":"pandas"}
headers = {
    'x-rapidapi-host': "alpha-vantage.p.rapidapi.com",
    'x-rapidapi-key': "<key>"
    }
ct_etc = requests.request("GET", url, headers=headers, params=querystring)
#print(ct_etc.text)

#<key>

# %%
url = "https://alpha-vantage.p.rapidapi.com/query"
querystring = {"market":"USD","symbol":"ETH","function":"DIGITAL_CURRENCY_DAILY","output_format":"pandas"}
headers = {
    'x-rapidapi-host': "alpha-vantage.p.rapidapi.com",
    'x-rapidapi-key': "<key>"
    }
ct_eth = requests.request("GET", url, headers=headers, params=querystring)
#print(ct_etc.text)

#<key>

# %%
url = "https://alpha-vantage.p.rapidapi.com/query"
querystring = {"market":"USD","symbol":"XRP","function":"DIGITAL_CURRENCY_DAILY","output_format":"pandas"}
headers = {
    'x-rapidapi-host': "alpha-vantage.p.rapidapi.com",
    'x-rapidapi-key': "<key>"
    }
ct_xrp = requests.request("GET", url, headers=headers, params=querystring)
#print(ct_etc.text)

#<key>

# %%
url = "https://alpha-vantage.p.rapidapi.com/query"
querystring = {"market":"USD","symbol":"XLM","function":"DIGITAL_CURRENCY_DAILY","output_format":"pandas"}
headers = {
    'x-rapidapi-host': "alpha-vantage.p.rapidapi.com",
    'x-rapidapi-key': "<key>"
    }
ct_xlm = requests.request("GET", url, headers=headers, params=querystring)
#print(ct_etc.text)

#<key>

# %%
url = "https://alpha-vantage.p.rapidapi.com/query"
querystring = {"market":"USD","symbol":"TRX","function":"DIGITAL_CURRENCY_DAILY","output_format":"pandas"}
headers = {
    'x-rapidapi-host': "alpha-vantage.p.rapidapi.com",
    'x-rapidapi-key': "<key>"
    }
ct_trx = requests.request("GET", url, headers=headers, params=querystring)
#print(ct_etc.text)

#<key>

# %%
#Create DF for Cryptos
ct_df=pd.DataFrame()
# Add each crypto coin and repeat for the crypto needed
ct_dic_btc=ct_btc.json()
md_btc=ct_dic_btc.pop('Meta Data', "default")
ct_df_btc_tr=pd.DataFrame(ct_dic_btc['Time Series (Digital Currency Daily)'])
ct_df_btc = ct_df_btc_tr.transpose().astype(float)
print(ct_df_btc.shape)
ct_df[md_btc['2. Digital Currency Code']] = ct_df_btc['4a. close (USD)'] 

ct_dic_etc=ct_etc.json()
md_etc=ct_dic_etc.pop('Meta Data', "default")
ct_df_etc_tr=pd.DataFrame(ct_dic_etc['Time Series (Digital Currency Daily)'])
ct_df_etc = ct_df_etc_tr.transpose().astype(float)
print(ct_df_etc.shape)
ct_df[md_etc['2. Digital Currency Code']] = ct_df_etc['4a. close (USD)'] 

ct_dic_eth=ct_eth.json()
md_eth=ct_dic_eth.pop('Meta Data', "default")
ct_df_eth_tr=pd.DataFrame(ct_dic_eth['Time Series (Digital Currency Daily)'])
ct_df_eth = ct_df_eth_tr.transpose().astype(float)
print(ct_df_eth.shape)
ct_df[md_eth['2. Digital Currency Code']] = ct_df_eth['4a. close (USD)'] 

ct_dic_xrp=ct_xrp.json()
md_xrp=ct_dic_xrp.pop('Meta Data', "default")
ct_df_xrp_tr=pd.DataFrame(ct_dic_xrp['Time Series (Digital Currency Daily)'])
ct_df_xrp = ct_df_xrp_tr.transpose().astype(float)
print(ct_df_xrp.shape)
ct_df[md_xrp['2. Digital Currency Code']] = ct_df_xrp['4a. close (USD)'] 

ct_dic_xlm=ct_xlm.json()
md_xlm=ct_dic_xlm.pop('Meta Data', "default")
ct_df_xlm_tr=pd.DataFrame(ct_dic_xlm['Time Series (Digital Currency Daily)'])
ct_df_xlm = ct_df_xlm_tr.transpose().astype(float)
print(ct_df_xlm.shape)
ct_df[md_xlm['2. Digital Currency Code']] = ct_df_xlm['4a. close (USD)'] 

ct_dic_trx=ct_trx.json()
md_trx=ct_dic_trx.pop('Meta Data', "default")
ct_df_trx_tr=pd.DataFrame(ct_dic_trx['Time Series (Digital Currency Daily)'])
ct_df_trx = ct_df_trx_tr.transpose().astype(float)
print(ct_df_trx.shape)
ct_df[md_trx['2. Digital Currency Code']] = ct_df_trx['4a. close (USD)']
# Out:
# (1000, 10)
# (702, 10)
# (1000, 10)
# (741, 10)
# (714, 10)
# (703, 10)

# %%
ct_df.index = pd.to_datetime(ct_df.index)
ct_df.plot()


# datein = '2017-01-01'
# date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
# dateout = '2020-05-13'
# date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.title('Top Cryptos')
# plt.xlim([date_in.date(),date_out.date()])
plt.show()

# %%
ct_df.plot()

datein = '2017-07-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.title('Top Cryptos')
plt.xlim([date_in.date(),date_out.date()])
plt.show()

# %%
ct_df['BTC'].plot()

datein = '2017-07-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.title('BTC')
plt.xlim([date_in.date(),date_out.date()])
plt.show()

# %%
ct_df['ETC'].plot()

datein = '2017-07-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.title('ETC')
plt.xlim([date_in.date(),date_out.date()])
plt.show()

# %%
ct_df['ETH'].plot()

datein = '2017-07-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.title('ETH')
plt.xlim([date_in.date(),date_out.date()])
plt.show()

# %%
ct_df['TRX'].plot()

datein = '2017-07-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.title('TRX')
plt.xlim([date_in.date(),date_out.date()])
plt.show()

# %%
ct_df['XRP'].plot()

datein = '2017-07-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.title('XRP')
plt.xlim([date_in.date(),date_out.date()])
plt.show()

# %%
ct_df['XLM'].plot()

datein = '2017-07-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

plt.title('XLM')
plt.xlim([date_in.date(),date_out.date()])
plt.show()

# %%
url = 'https://www.federalreserve.gov/paymentsystems/coin_currcircvalue.htm'
html = requests.get(url).content
soup=BeautifulSoup(html,'lxml')
soup.title.text
# Out:
# 'Federal Reserve Board - Currency in Circulation: Value'

# %%
# Get column names
index = soup.find_all('tr',{'class':'header'})
list_col = soup.find_all('th',{'scope':'col'})
nomcol = [list.text.replace('\n','').replace('\t','') for list in list_col]

#Get data of the table and header of the table
yearlist = soup.find_all('td',{'class':'left'})
usdlist = soup.find_all('td',{'class':'left2'})
year = [list.text.replace('\n','').replace('\t','') for list in yearlist]
usd = [list.text.replace('\n','').replace('\t','') for list in usdlist]

#Form the correct shape for the date
npyear= np.array(year)
npusd= np.array(usd)
npyearc=npyear.reshape(21,1)
npusdc=npusd.reshape(21,9)
npyear = [list.replace(',','') for list in npyear]

#Create DataFrame
usd_cry_df = pd.DataFrame(npusdc,index=npyear,columns=nomcol[1:])


#Create DataFrame in float type
usd_cry_df2=pd.DataFrame()
usd_cry_df2 = usd_cry_df[usd_cry_df.columns[1:]].replace('[\$,]', '', regex=True).astype(float)
#print(usd_cry_df2)

#Plot Data Frame
usd_cry_df.index = pd.to_datetime(usd_cry_df.index)
usd_cry_df2.index = pd.to_datetime(usd_cry_df2.index)
usd_cry_df2['Total'].plot()
plt.title(soup.title.text)
plt.show()
print(usd_cry_df)
# Out:
#                $1    $2     $5    $10     $20    $50      $100 $500 to$10,000  \
# 2018-01-01  $12.4  $2.5  $15.3  $20.1  $188.5  $89.2  $1,343.5           $0.3
# 2017-01-01  $12.1  $2.4  $14.8  $19.6  $183.8  $86.4  $1,251.7           $0.3
# 2016-01-01  $11.7  $2.3  $14.2  $19.2  $177.2  $83.5  $1,154.8           $0.3
# 2015-01-01  $11.4  $2.3  $13.7  $19.0  $171.3  $79.8  $1,082.2           $0.3
# 2014-01-01  $11.0  $2.2  $13.1  $18.9  $162.2  $76.9  $1,014.5           $0.3
# 2013-01-01  $10.6  $2.1  $12.7  $18.5  $155.0  $74.5    $924.7           $0.3
# 2012-01-01  $10.3  $2.0  $12.2  $17.7  $148.9  $72.5    $863.1           $0.3
# 2011-01-01  $10.0  $1.9  $11.8  $17.2  $141.1  $69.6    $782.6           $0.3
# 2010-01-01   $9.7  $1.8  $11.5  $16.6  $130.6  $66.9    $704.6           $0.3
# 2009-01-01   $9.6  $1.7  $11.2  $16.2  $127.5  $65.3    $656.4           $0.3
# 2008-01-01   $9.5  $1.7  $11.0  $16.3  $125.1  $64.7    $625.0           $0.3
# 2007-01-01   $9.3  $1.6  $10.8  $16.2  $121.8  $63.0    $569.3           $0.3
# 2006-01-01   $9.0  $1.5  $10.5  $16.0  $119.2  $62.8    $564.1           $0.3
# 2005-01-01   $8.8  $1.5  $10.3  $15.5  $115.4  $62.1    $545.0           $0.3
# 2004-01-01   $8.3  $1.4   $9.8  $15.1  $107.6  $60.6    $516.7           $0.3
# 2003-01-01   $8.2  $1.3   $9.7  $15.1  $107.8  $59.9    $487.8           $0.3
# 2002-01-01   $8.0  $1.3   $9.4  $14.9  $103.7  $58.5    $458.7           $0.3
# 2001-01-01   $7.8  $1.3   $9.2  $14.7  $100.9  $57.0    $421.1           $0.3
# 2000-01-01   $7.7  $1.2   $8.9  $14.5   $98.6  $55.0    $377.7           $0.3
# 1999-01-01   $7.5  $1.2   $9.0  $16.2  $116.1  $64.7    $386.2           $0.3
# 1998-01-01   $7.0  $1.2   $8.0  $14.3   $90.9  $50.5    $320.1           $0.3
#
#                Total
# 2018-01-01  $1,671.9
# 2017-01-01  $1,571.1
# 2016-01-01  $1,463.4
# 2015-01-01  $1,380.0
# 2014-01-01  $1,299.1
# 2013-01-01  $1,198.3
# 2012-01-01  $1,127.1
# 2011-01-01  $1,034.5
# 2010-01-01    $942.0
# 2009-01-01    $888.3
# 2008-01-01    $853.2
# 2007-01-01    $792.2
# 2006-01-01    $783.5
# 2005-01-01    $758.8
# 2004-01-01    $719.9
# 2003-01-01    $690.2
# 2002-01-01    $654.8
# 2001-01-01    $612.3
# 2000-01-01    $563.9
# 1999-01-01    $601.2
# 1998-01-01    $492.2

# %%
datein = '2017-07-01'
date_in = datetime.datetime.strptime(datein, '%Y-%m-%d')
dateout = '2020-05-13'
date_out = datetime.datetime.strptime(dateout, '%Y-%m-%d')

usd_cry_df2['Total'].plot()
plt.xlim([date_in.date(),date_out.date()])
plt.ylim(1400,1900)
plt.title(soup.title.text)
plt.show()

# %%
s_df.to_csv('Stock_Tech_DF.csv')
sb_df.to_csv('Stock_Banks_DF.csv')
ct_df.to_csv('Crypto_DF.csv')
usd_cry_df.to_csv('Dollars_in_Circulation_USD.csv')
usd_cry_df2.to_csv('Dollars_in_Circulation_float.csv')
