# %% [markdown]
# # Serial killers with the highest known victim count

# %%
#Importar las librerías que nos ayudarán a correr el código. 

from bs4 import BeautifulSoup #librería para hacer parse de documentos HTML
import requests #librería para hacer los requests a la página que se va a scrappear 
import pandas as pd #librería para análisis de datos 
import re #librería para limpieza de la información 
import datanews #API 
import urllib.parse #librería para hacer el encoding de los url 
import json #librería para parsing
import time #librería para dar un intervalo de tiempo dentro de un loop
import numpy as np #librería para trabajar con arrays

# %% [markdown]
# ### Web Scrapping de Wikipedia.

# %%
#Dar la instrucción de scrappear el contenido de la página de Wikipedia donde vienen la lista de los asesinos
#seriales rankeados por número de víctimas. Para ordenar la información y que sea más legible usamos Beautiful Soup. 

wiki = requests.get("https://en.wikipedia.org/wiki/List_of_serial_killers_by_number_of_victims").content
soup = BeautifulSoup(wiki, 'html5lib')

#De todo el contenido de la página, solo me interesa la tabla donde viene agrupada la info que necesito 
#Con Inspect identifiqué que la class que necesito llamar es "wikitable sortable"

killers_info = soup.select('table[class="wikitable sortable"]')

#La información seleccionada es limpiada. 

clean_killers_info = [th.text.strip().replace("\xa0",",").split('\n\n\n') for th in killers_info]

#De la clase que identificamos, solo necesitamos la primera tabla que corresponde a los asesinos seriales 
#con mayor número de víctimas, por lo que iteramos, la seleccionamos y asignamos a una variable nueva 

killer_chart = clean_killers_info[0]

# %%
#Es necesario hacer una segunda limpieza para quitar los caracteres que ensucian la información y después creamos 
#una lista para guardar la información.

clean_killer_chart = [x.strip().replace(",", " ").split("\n\n") for x in killer_chart]

new_df=[]
for row in clean_killer_chart:
    new_row=[]
    for element in row:
        new_row.append(re.sub(r'\[\d*]','',element))
    new_df.append(new_row)

#Una vez que la información ya está limpia, utilizamos pandas para crear un dataframe
#Indicamos cuáles queremos que sean los nombres de las columnas 
#Eliminamos filas que no hacen sentido con la tabla y que no tienen información relevante 

df_killers = pd.DataFrame(new_df, columns = new_df[0]).drop([0])
df_killers
# Out:
#                                                  Name  \
# 1                                       Luis Garavito
# 2                                         Pedro López
# 3                                         Javed Iqbal
# 4                                      Mikhail Popkov
# 5                              Daniel Camargo Barbosa
# 6                               Pedro Rodrigues Filho
# 7                               Kampatimar Shankariya
# 8                                         Yang Xinhai
# 9                                    Andrei Chikatilo
# 10                                 Anatoly Onoprienko
# 11                                  Ivan S. Maleshoff
# 12                                      Samuel Little
# 13                            Florisvaldo de Oliveira
# 14                                      Willy Pickton
# 15                                       Gary Ridgway
# 16                               Alexander Pichushkin
# 17                                         Wang Qiang
# 18                                      Ahmad Suradji
# 19                                       Raman Raghav
# 20                      Tiago Henrique Gomes da Rocha
# 21                                      Moses Sithole
# 22                                       Serhiy Tkach
# 23                                Gennady Mikhasevich
# 24                              Hadj Mohammed Mesfewi
# 25                                        Vera Renczi
# 26                                          Ted Bundy
# 27                                Clementine Barnabet
# 28                                    John Wayne Gacy
# 29                               Ali Asghar Borujerdi
# 30                                    Vasili Komaroff
# 31  Fernando Hernández Leyva\n Mexico\n1982 to 199...
# 32                        Ramadan Abdel Rehim Mansour
# 33                                       Volga Maniac
#
#                                    Country      Years active Proven victims  \
# 1               Colombia Ecuador Venezuela      1992 to 1999            138
# 2                    Colombia Peru Ecuador      1969 to 1979            110
# 3                                 Pakistan      1998 to 1999            100
# 4                                   Russia      1992 to 2010             83
# 5        Colombia Ecuador Brazil (alleged)      1974 to 1986             72
# 6                                   Brazil      1967 to 2003             71
# 7                                    India      1977 to 1978             70
# 8                                    China      2000 to 2003             67
# 9                             Soviet Union      1978 to 1990             53
# 10                    Soviet Union Ukraine      1989 to 1996             52
# 11                            Soviet Union      1934 to 1935             50
# 12                           United States      1970 to 2005             50
# 13                                  Brazil              1982             50
# 14                                  Canada      1983 to 2002             49
# 15                           United States      1982 to 2000             49
# 16                                  Russia      1992 to 2006             48
# 17                                   China      1995 to 2003             45
# 18                               Indonesia      1986 to 1997             42
# 19                                   India      1965 to 1968             41
# 20                                  Brazil      2011 to 2014             39
# 21                            South Africa      1994 to 1995             38
# 22                    Soviet Union Ukraine      1984 to 2005             36
# 23                            Soviet Union      1971 to 1985             36
# 24                                 Morocco  1906 and earlier             36
# 25   Romania  Yugoslavia Hungary (alleged)      1920 to 1930             35
# 26                           United States      1974 to 1978             35
# 27                           United States              1911             35
# 28                           United States      1972 to 1978             33
# 29                Ottoman Empire Iraq Iran      1907 to 1934             33
# 30                            Soviet Union      1921 to 1923             33
# 31                                    None              None           None
# 32                                   Egypt      1999 to 2006             32
# 33                                  Russia      2011 to 2012             32
#
#    Possible victims                                              Notes
# 1          172–300+  Child-murderer  torture-killer  and rapist kno...
# 2              300+  Child-murderer and rapist  known as "The Monst...
# 3               100  Child-murderer and rapist  known as "Kukri"  I...
# 4               83+  Serial rapist-killer nicknamed "The Werewolf" ...
# 5               180  Child and woman murderer  believed to have pos...
# 6              100+  He claimed to have killed over 100 victims  47...
# 7               70+  This mysterious Indian serial killer used a ha...
# 8                67  Known as the "Monster Killer". Would enter vic...
# 9                56  Known as "The Butcher of Rostov"  "The Red Rip...
# 10              52+  Known as "The Beast of Ukraine"  "The Terminat...
# 11               50  Known as  "Bluebeard of Kharkiv"; Ivan Stepano...
# 12               93  Was convicted of killing three women  but late...
# 13              50+  Known as "Cabo Bruno"; former police officer a...
# 14               49  Nicknamed "The Butcher"; Robert Pickton was a ...
# 15           71–90+  Truck painter who confessed to killing 71 wome...
# 16               60  Known as the Chessboard Killer. Convicted of m...
# 17              60+  Killed 45 and raped 10 from 1995 to 2003. Exec...
# 18           70–80+  Convicted of strangling at least 42 women and ...
# 19               41  In the late 1960s Raman Raghav went on a viole...
# 20              ~39  Brazilian security guard who confessed to the ...
# 21              38+  Known as South Africa's Ted Bundy. Preyed on u...
# 22           80–100  A former Ukrainian police criminal investigato...
# 23           43–55+  Strangled women. Besides killing  he also robb...
# 24              36+  Known as "Marrakesh Arch-Killer"; drugged  mut...
# 25              ~35  Romanian serial killer nicknamed  "The Black W...
# 26          36–100+  American serial killer known for his charisma ...
# 27               35  An axe murdering voodoo priestess who murdered...
# 28              34+  Known to have murdered a minimum of 33 teenage...
# 29               33  Known as "Asghar the Murderer". Killed 33 youn...
# 30               33  Known as "The Wolf of Moscow"; horse trader wh...
# 31             None                                               None
# 32              32+  Gang leader known as al-Tourbini ("The Express...
# 33               32  Killed elderly women in several Russian region...

# %%
#La fila 31 es la única que sale mal.
#Nos damos cuenta que falta separar por columna '\n' en la columna "Name" que es donde se quedó toda la info
#lo asignamos a una variable para después usarla para asignar un valor 

row_31 = df_killers.loc[31]['Name'].split('\n') 

#Una vez que ya tenemos la info separada en una lista, iteramos sobre cada columna e índice 
#para asignar cada valor que le corresponde según la lista que creamos arriba. 

for cell,column in enumerate(df_killers.columns):
    df_killers.loc[31][column] = row_31[cell]

# %% [markdown]
# ### Llamada a la API de "Data News" y consolidación de la información.

# %%
#Por el nombre de cada asesino hacemos un request para almacenar el URL con la noticia relacionada al asesino.
#Si no se encuentra una noticia para el asesino, asignamos "No news found". 
#Usamos la librería urllib para el encoding de URL.
#Guardamos la información en un diccionario.

news = {}

for name in df_killers['Name']:
    url = f'http://api.datanews.io/v1/news?q=%22{urllib.parse.quote(name)}%22'
    info = requests.get(url, headers = {'x-api-key': '04rolxy69c1vzr6wi5xplfqyf'})
    if info.json()['numResults'] != 0:
        news[name]=(info.json()['hits'][0]['url'])
    else:
        news[name]='No news found'
        time.sleep(2)

        
#La información que guardamos en el diccionario la pasamos a un dataframe para visualización. 
df_news = pd.DataFrame(news, index=[0]).T.rename(columns={0: 'url'})

#Unimos el dataframe que contiene la información de los asesinos seriales con la que contiene el url de la 
#noticia por asesino para consolidar los resultados.Tenemos que hacer que coincidan en el índice, por lo que en 
#df_killers pasamos la columna "Name" como el índice y posterior hacemos el join. 

df_killers = df_killers.set_index(df_killers['Name'], drop=False).drop('Name',axis=1)
final_df = df_killers.join(df_news)

#Finalmente imprimimos el resultado 
final_df
# Out:
#                                                               Country  \
# Name
# Luis Garavito                              Colombia Ecuador Venezuela
# Pedro López                                     Colombia Peru Ecuador
# Javed Iqbal                                                  Pakistan
# Mikhail Popkov                                                 Russia
# Daniel Camargo Barbosa              Colombia Ecuador Brazil (alleged)
# Pedro Rodrigues Filho                                          Brazil
# Kampatimar Shankariya                                           India
# Yang Xinhai                                                     China
# Andrei Chikatilo                                         Soviet Union
# Anatoly Onoprienko                               Soviet Union Ukraine
# Ivan S. Maleshoff                                        Soviet Union
# Samuel Little                                           United States
# Florisvaldo de Oliveira                                        Brazil
# Willy Pickton                                                  Canada
# Gary Ridgway                                            United States
# Alexander Pichushkin                                           Russia
# Wang Qiang                                                      China
# Ahmad Suradji                                               Indonesia
# Raman Raghav                                                    India
# Tiago Henrique Gomes da Rocha                                  Brazil
# Moses Sithole                                            South Africa
# Serhiy Tkach                                     Soviet Union Ukraine
# Gennady Mikhasevich                                      Soviet Union
# Hadj Mohammed Mesfewi                                         Morocco
# Vera Renczi                     Romania  Yugoslavia Hungary (alleged)
# Ted Bundy                                               United States
# Clementine Barnabet                                     United States
# John Wayne Gacy                                         United States
# Ali Asghar Borujerdi                         Ottoman Empire Iraq Iran
# Vasili Komaroff                                          Soviet Union
# Fernando Hernández Leyva                                       Mexico
# Ramadan Abdel Rehim Mansour                                     Egypt
# Volga Maniac                                                   Russia
#
#                                    Years active Proven victims  \
# Name
# Luis Garavito                      1992 to 1999            138
# Pedro López                        1969 to 1979            110
# Javed Iqbal                        1998 to 1999            100
# Mikhail Popkov                     1992 to 2010             83
# Daniel Camargo Barbosa             1974 to 1986             72
# Pedro Rodrigues Filho              1967 to 2003             71
# Kampatimar Shankariya              1977 to 1978             70
# Alexander Pichushkin           Known as the Chessboard Killer. Convicted of m...
# Wang Qiang                     Killed 45 and raped 10 from 1995 to 2003. Exec...
# Ahmad Suradji                  Convicted of strangling at least 42 women and ...
# Raman Raghav                   In the late 1960s Raman Raghav went on a viole...
# Tiago Henrique Gomes da Rocha  Brazilian security guard who confessed to the ...
# Moses Sithole                  Known as South Africa's Ted Bundy. Preyed on u...
# Serhiy Tkach                   A former Ukrainian police criminal investigato...
# Gennady Mikhasevich            Strangled women. Besides killing  he also robb...
# Hadj Mohammed Mesfewi          Known as "Marrakesh Arch-Killer"; drugged  mut...
# Vera Renczi                    Romanian serial killer nicknamed  "The Black W...
# Ted Bundy                      American serial killer known for his charisma ...
# Clementine Barnabet            An axe murdering voodoo priestess who murdered...
# John Wayne Gacy                Known to have murdered a minimum of 33 teenage...
# Ali Asghar Borujerdi           Known as "Asghar the Murderer". Killed 33 youn...
# Vasili Komaroff                Known as "The Wolf of Moscow"; horse trader wh...
# Fernando Hernández Leyva       Confessed to 100 murders and six kidnappings a...
# Ramadan Abdel Rehim Mansour    Gang leader known as al-Tourbini ("The Express...
# Volga Maniac                   Killed elderly women in several Russian region...
#
#                                                                              url
# Name
# Luis Garavito                  https://www.vice.com/en_us/article/bv8bv4/the-...
# Pedro López                    https://www.heraldo.es/noticias/deportes/futbo...
# Javed Iqbal                    https://www.urdupoint.com/en/pakistan/death-an...
# Mikhail Popkov                 https://www.thesun.co.uk/news/12463599/serial-...
# Daniel Camargo Barbosa         https://www.vice.com/en_us/article/bv8bv4/the-...
# Pedro Rodrigues Filho          https://economia.uol.com.br/noticias/redacao/2...
# Kampatimar Shankariya                                              No news found
# Yang Xinhai                                                        No news found
# Andrei Chikatilo               https://www.newshub.co.nz/home/lifestyle/2020/...
# Anatoly Onoprienko                                                 No news found
# Ivan S. Maleshoff                                                  No news found
# Samuel Little                  https://heavy.com/entertainment/2020/08/how-wa...
# Florisvaldo de Oliveira                                            No news found
# Willy Pickton                                                      No news found
# Gary Ridgway                   https://www.rtl.fr/actu/international/le-tueur...
# Alexander Pichushkin           https://www.thesun.co.uk/news/12463599/serial-...
# Wang Qiang                     https://www.automotiveworld.com/news-releases/...
# Ahmad Suradji                                                      No news found
# Raman Raghav                   https://www.koimoi.com/box-office/fact-o-meter...
# Tiago Henrique Gomes da Rocha  http://entretenimento.r7.com/famosos-e-tv/came...
# Moses Sithole                                                      No news found
# Serhiy Tkach                   https://www.klikk.no/side3/historie/verdens-ve...
# Gennady Mikhasevich            https://www.rbth.com/lifestyle/332937-maniacs-...
# Hadj Mohammed Mesfewi                                              No news found
# Vera Renczi                                                        No news found
# Ted Bundy                      https://www.mlive.com/life/2020/10/ted-bundy-t...
# Clementine Barnabet            http://populove.net/cell-structure/family-anni...
# John Wayne Gacy                https://www.mediaite.com/tv/watch-snls-weekend...
# Ali Asghar Borujerdi                                               No news found
# Vasili Komaroff                                                    No news found
# Fernando Hernández Leyva                                           No news found
# Ramadan Abdel Rehim Mansour                                        No news found
# Volga Maniac                                                       No news found

# %% [markdown]
# ### Save final data to CSV.

# %%
#Guardar la información en un CSV para análises posteriores. 

final_df.to_csv('serial_killers.csv', index = False)
