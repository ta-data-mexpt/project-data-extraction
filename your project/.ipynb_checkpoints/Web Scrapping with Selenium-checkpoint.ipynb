# %% [markdown]
# #### Web Scrapping with Selenium

# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
driver = webdriver.Chrome()

# %%
url="https://www.scrapethissite.com/pages/simple/"

# %%
driver.get(url)

# %%
#<div class="col-md-4 country">
countries_data=driver.find_elements("xpath",'//*[@class="col-md-4 country"]/div')
countries_data

#<div class="country-info">                          
#countries_data=driver.find_elements("xpath",'//*[@class="country-info"]/div')
#countries_data
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="7fee4503-4537-4719-835b-09bf63189e80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="fba57e52-898e-4506-bae4-1e461bba6f53")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="65b85191-5430-42ab-b72a-4fd2b385d5d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="16d725ba-4474-43a2-a4ec-d67757d3dbf5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="ab7d8538-b454-4795-bdf3-1f0e842c89bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="4ff86a63-7b4c-4d87-accc-185b5b621b0e")>,
# ...

# %%
countries_data_1=[]
for country in countries_data:
    country_information_2=country.text
    countries_data_1.append(country_information_2)
countries_data_1
# Out:
# ['Capital: Andorra la Vella\nPopulation: 84000\nArea (km2): 468.0',
#  'Capital: Abu Dhabi\nPopulation: 4975593\nArea (km2): 82880.0',
#  'Capital: Kabul\nPopulation: 29121286\nArea (km2): 647500.0',
#  "Capital: St. John's\nPopulation: 86754\nArea (km2): 443.0",
#  'Capital: The Valley\nPopulation: 13254\nArea (km2): 102.0',
#  'Capital: Tirana\nPopulation: 2986952\nArea (km2): 28748.0',
#  'Capital: Yerevan\nPopulation: 2968000\nArea (km2): 29800.0',
#  'Capital: Luanda\nPopulation: 13068161\nArea (km2): 1246700.0',
#  'Capital: None\nPopulation: 0\nArea (km2): 1.4E7',
#  'Capital: Buenos Aires\nPopulation: 41343201\nArea (km2): 2766890.0',
#  'Capital: Pago Pago\nPopulation: 57881\nArea (km2): 199.0',
#  'Capital: Vienna\nPopulation: 8205000\nArea (km2): 83858.0',
#  'Capital: Canberra\nPopulation: 21515754\nArea (km2): 7686850.0',
#  'Capital: Oranjestad\nPopulation: 71566\nArea (km2): 193.0',
#  'Capital: Mariehamn\nPopulation: 26711\nArea (km2): 1580.0',
# ...

# %%
len(countries_1)
# Out:
# 250

# %%
countries_1[249]
# Out:
# 'Capital: Harare\nPopulation: 11651858\nArea (km2): 390580.0'

# %%
#<h3 class="country-name">
country_name=driver.find_elements("xpath",'//*["country-name"]/h3')
country_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="a78f5b80-bd18-481a-b1bc-e87ddbeb17c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="0a10e416-4f18-4ffe-874c-59441fb4f46f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="191ddbe6-28dc-433c-b6a2-1e3ba3411694")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="dc5fb9aa-219a-466d-a2a9-4d53df452c6b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="e221b959-b4bc-4dc8-8b48-4c8374a1f574")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="fa033f04-daed-43b5-8b6b-50a9970c4165")>,
# ...

# %%
country_name_1=[]
for country in country_name:
    country_information_1=country.text
    country_name_1.append(country_information_1)
country_name_1
# Out:
# ['Andorra',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Antigua and Barbuda',
#  'Anguilla',
#  'Albania',
#  'Armenia',
#  'Angola',
#  'Antarctica',
#  'Argentina',
#  'American Samoa',
#  'Austria',
#  'Australia',
#  'Aruba',
#  'Åland',
#  'Azerbaijan',
#  'Bosnia and Herzegovina',
#  'Barbados',
#  'Bangladesh',
#  'Belgium',
#  'Burkina Faso',
#  'Bulgaria',
#  'Bahrain',
#  'Burundi',
#  'Benin',
#  'Saint Barthélemy',
#  'Bermuda',
#  'Brunei',
#  'Bolivia',
#  'Bonaire',
#  'Brazil',
#  'Bahamas',
#  'Bhutan',
#  'Bouvet Island',
#  'Botswana',
#  'Belarus',
#  'Belize',
#  'Canada',
#  'Cocos [Keeling] Islands',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Republic of the Congo',
#  'Switzerland',
#  'Ivory Coast',
#  'Cook Islands',
#  'Chile',
#  'Cameroon',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Cape Verde',
#  'Curacao',
#  'Christmas Island',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Djibouti',
# ...

# %%
len(country_name_1)
# Out:
# 250

# %%
#<h3 class="country-name">
country_population=driver.find_elements("xpath",'//*[@class="country-info"]/span')
country_population
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="a3841fd2-bd0d-4257-8dd9-4bc9badaa57c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="79e356bc-228e-4183-804e-2ae9497deb7f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="46afcb0d-83fe-4af4-8e17-b6b105c77344")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="7c073203-dbaa-41c7-82a9-3f3dcbd24c72")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="e7f0d10c-a2f2-44a7-b54f-d10e1a7681f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="76200fb75b19320f4e8e8d0b07c40c87", element="75458c83-d7f3-4672-bccb-e0d8e8158c94")>,
# ...

# %%
country_population_1=[]
for country in country_population:
    country_information_3=country.text
    country_population_1.append(country_information_3)
country_population_1
# Out:
# ['Andorra la Vella',
#  '84000',
#  '468.0',
#  'Abu Dhabi',
#  '4975593',
#  '82880.0',
#  'Kabul',
#  '29121286',
#  '647500.0',
#  "St. John's",
#  '86754',
#  '443.0',
#  'The Valley',
#  '13254',
#  '102.0',
#  'Tirana',
#  '2986952',
#  '28748.0',
#  'Yerevan',
#  '2968000',
#  '29800.0',
#  'Luanda',
#  '13068161',
#  '1246700.0',
#  'None',
#  '0',
#  '1.4E7',
#  'Buenos Aires',
#  '41343201',
#  '2766890.0',
#  'Pago Pago',
#  '57881',
#  '199.0',
#  'Vienna',
#  '8205000',
#  '83858.0',
#  'Canberra',
#  '21515754',
#  '7686850.0',
#  'Oranjestad',
#  '71566',
#  '193.0',
#  'Mariehamn',
#  '26711',
#  '1580.0',
#  'Baku',
#  '8303512',
#  '86600.0',
#  'Sarajevo',
#  '4590000',
#  '51129.0',
#  'Bridgetown',
#  '285653',
#  '431.0',
#  'Dhaka',
#  '156118464',
#  '144000.0',
#  'Brussels',
#  '10403000',
#  '30510.0',
#  'Ouagadougou',
#  '16241811',
#  '274200.0',
#  'Sofia',
#  '7148785',
#  '110910.0',
#  'Manama',
#  '738004',
#  '665.0',
#  'Bujumbura',
#  '9863117',
# ...

# %%
len(country_population_1)
# Out:
# 750

# %%
type(country_population_1)
# Out:
# list

# %%
all(isinstance(n, str) for n in country_population_1)
# Out:
# True

# %%
country_population_1[0+3]
# Out:
# 'Abu Dhabi'

# %%
#"lst = list(range(1000))" "lst1 = [x for x in lst if x % 10 == 0]"
#capitals
Capital= country_population_1[::3]
#population
Population = country_population_1[1::3]
#area
Area_km2 = country_population_1[2::3]

# %%
len(newlist)
# Out:
# 250

# %%
df=pd.DataFrame()
df['Country']=country_name_1
df['Capital']=Capital
df['Population']=Population
df['Area(km2)']=Area_km2
df.head()
# Out:
#                 Country           Capital Population Area(km2)
# 0               Andorra  Andorra la Vella      84000     468.0
# 1  United Arab Emirates         Abu Dhabi    4975593   82880.0
# 2           Afghanistan             Kabul   29121286  647500.0
# 3   Antigua and Barbuda        St. John's      86754     443.0
# 4              Anguilla        The Valley      13254     102.0

# %%
df.to_csv('countries_information.csv',index=False)

# %%
driver.quit()
