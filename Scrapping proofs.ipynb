# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url_gg = 'https://lan.op.gg/statistics/champion/'
html_gg = requests.get(url_gg).content
soup_gg = BeautifulSoup(html_gg)

# %%
table_gg = soup_gg.find_all('div',{'class':'ChampionStatsTable'})
table_gg
# Out:
# []

# %%
soup_gg
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <script async="true" id="__zeus_script" src="https://ugg.zeustechnology.com/main.js"></script><script type="application/javascript">document.getElementById("__zeus_script").onload=function(){if (window.hasOwnProperty(zeus) && window.zeus.hasOwnProperty(run)) window.zeus.run()}</script>
# <!-- Amazon Publisher Services (ads) -->
# <script>
#               //load the apstag.js library
#               !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#               </script>
# <meta charset="utf-8"/>
# ...

# %%
url_gg = 'https://champion.gg/statistics/?league=bronze'
html_gg = requests.get(url_gg).content
soup_gg = BeautifulSoup(html_gg, "lxml")

# %%
table_gg = soup_gg.find_all('td')
print(len(table_gg))
df = pd.DataFrame(table_gg)
df
# Out:
# 60
#                                                     0
# 0                                            [[Rank]]
# 1                                        [[Champion]]
# 2                                            [[Role]]
# 3                                     [[Win Percent]]
# 4                                    [[Play Percent]]
# 5                                        [[Ban Rate]]
# 6                           [[Playerbase Avg. Games]]
# 7                                           [[Kills]]
# 8                                          [[Deaths]]
# 9                                         [[Assists]]
# 10                          [[Largest Killing Spree]]
# 11                                   [[Damage Dealt]]
# 12                                   [[Damage Taken]]
# 13                                  [[Total Healing]]
# 14                                 [[Minions Killed]]
# 15                                [[Enemy Jungle CS]]
# ...

# %%
# obtenemos los nombres
name_gg = soup_gg.find_all('div',{'class':"tsm-tooltip tsm-angular-champion-tt"})

# %%
name_gg
# Out:
# [<div class="tsm-tooltip tsm-angular-champion-tt" data-id="{{matchupData}}" data-name="{{champion.key}}" data-type="champions">
#  <div class="matchup-champion {{champion.key}}" style="background-image: url('//ddragon.leagueoflegends.com/cdn/10.9.1/img/champion/{{ championsStatic[champion.key].image }}')"></div>
#  <span class="stat-champ-title">{{champion.title}}</span>
#  </div>]
